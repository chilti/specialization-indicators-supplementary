# %% [markdown]
# # Comparison of Global Context Correlations: All Documents vs. Citable Documents
#
# This notebook performs a systematic comparison between the correlations calculated for **All Documents** and **Citable Documents** in the Global Context across different ESI (Essential Science Indicators) fields.

# %%
#Montar mi google drive para poder usar los archivos
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments/Global Context/"
# !ls
# Out:
# /content/gdrive/.shortcut-targets-by-id/0B5aSrRJgnViLfm9LWl9TY21TWm5wSU0zbkgzc2YyeEp3RzJMaEJOR2FWbFkxVEZYTjNQd1E/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments/Global Context
# ai.txt				 pearson_correlation_AI_FMeasure.csv
# AMEASURE.txt			 rsi.txt
# AreasShare.xlsx			 scatterplots
# figuras				 scatterplots.html
# FMEASURE.txt			 share.txt
# GAggregation.txt		 Spearman_correlation_AI_FMeasure.csv
# GMEASURE.txt			 Wshare.txt
# manuscriptFiguresAndTables.html

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set plotting style
sns.set_theme(style="whitegrid")
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['DejaVu Sans', 'Arial', 'Helvetica'],
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titlesize': 14,
    'figure.titleweight': 'bold'
})


# Initialize HTML report container
text = """
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>Comparison Analysis Report</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; color: #2c3e50; }
        h1, h2, h3 { color: #2c3e50; }
        table { border-collapse: collapse; width: 100%; margin-bottom: 20px; }
        th, td { border: 1px solid #bdc3c7; padding: 8px; text-align: left; }
        th { background-color: #f4f6f7; font-weight: bold; }
        img { max-width: 100%; height: auto; display: block; margin: 20px 0; }
    </style>
</head>
<body>
<h1>Comparison Analysis Report (All vs. Citable Documents)</h1>
"""

# %%
# Define paths to the CSV files
paths = {
    'all_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments/Global Context/pearson_correlation_AI_FMeasure.csv',
    'all_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments/Global Context/Spearman_correlation_AI_FMeasure.csv',
    'citable_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments2026/InCites/Global Context/pearson_correlation_AI_FMeasure.csv',
    'citable_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments2026/InCites/Global Context/Spearman_correlation_AI_FMeasure.csv'
}

# Load files
dfs = {}
for name, path in paths.items():
    if not os.path.exists(path):
        # Try relative paths as fallback
        if '2026' in path:
            rel_path = f'Global Context/{os.path.basename(path)}'
        else:
            rel_path = f'../../ManuscriptExperiments/Global Context/{os.path.basename(path)}'
        if os.path.exists(rel_path):
            path = rel_path

    dfs[name] = pd.read_csv(path, index_col=0)
    print(f"Successfully loaded {name} (Shape: {dfs[name].shape})")
# Out:
# Successfully loaded all_pearson (Shape: (22, 11))
# Successfully loaded all_spearman (Shape: (22, 11))
# Successfully loaded citable_pearson (Shape: (22, 11))
# Successfully loaded citable_spearman (Shape: (22, 11))

# %%
def get_comparison_table(col_name):
    """
    Creates a side-by-side comparison table for a specific correlation column.
    """
    # Base index of ESI fields from the Pearson All dataset
    index_ref = dfs['all_pearson'].index

    df_comp = pd.DataFrame(index=index_ref)

    # Pearson
    df_comp['Pearson (All)'] = dfs['all_pearson'][col_name]
    df_comp['Pearson (Citable)'] = dfs['citable_pearson'][col_name]
    df_comp['Pearson Diff (Citable - All)'] = df_comp['Pearson (Citable)'] - df_comp['Pearson (All)']

    # Spearman (aligning indices)
    df_comp['Spearman (All)'] = df_comp.index.map(dfs['all_spearman'][col_name])
    df_comp['Spearman (Citable)'] = df_comp.index.map(dfs['citable_spearman'][col_name])
    df_comp['Spearman Diff (Citable - All)'] = df_comp['Spearman (Citable)'] - df_comp['Spearman (All)']

    # Sort ESI Fields alphabetically
    df_comp = df_comp.sort_index()
    return df_comp

def display_styled_table(df, title):
    """
    Applies advanced pandas styler to color-code difference columns and display.
    """
    styled = df.style.format("{:.4f}")\
        .background_gradient(cmap="coolwarm", subset=["Pearson Diff (Citable - All)", "Spearman Diff (Citable - All)"], vmin=-0.2, vmax=0.2)\
        .set_caption(f"<b style='font-size: 14px;'>{title}</b>")\
        .set_table_styles([
            {'selector': 'th', 'props': [('background-color', '#f4f6f7'), ('color', '#2c3e50'), ('font-weight', 'bold'), ('text-align', 'center')]},
            {'selector': 'td', 'props': [('text-align', 'right')]},
            {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
        ])
    display(styled)
    global text
    text = text + f"<h2>{title}</h2>" + styled.to_html() + "<br><br>"

def plot_comparison(df, user_name):
    """
    Generates side-by-side horizontal bar plots to visualize the differences in correlations.
    """
    # Prepare Pearson data for Seaborn
    df_pearson = pd.DataFrame({
        'ESI Field': df.index,
        'All Documents': df['Pearson (All)'].values,
        'Citable Documents': df['Pearson (Citable)'].values
    }).melt(id_vars='ESI Field', var_name='Dataset', value_name='Pearson Correlation')

    # Prepare Spearman data for Seaborn
    df_spearman = pd.DataFrame({
        'ESI Field': df.index,
        'All Documents': df['Spearman (All)'].values,
        'Citable Documents': df['Spearman (Citable)'].values
    }).melt(id_vars='ESI Field', var_name='Dataset', value_name='Spearman Correlation')

    fig, axes = plt.subplots(1, 2, figsize=(16, 9), sharey=True)

    # Harmonious colors: Cool Blue for All, Warm Coral for Citable
    colors = {'All Documents': '#2b7bba', 'Citable Documents': '#e76f51'}

    # Pearson Subplot
    sns.barplot(
        data=df_pearson,
        y='ESI Field',
        x='Pearson Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[0]
    )
    axes[0].set_title("Pearson Correlation Coefficient", fontsize=13, pad=10)
    axes[0].set_xlabel("Correlation Value")
    axes[0].set_ylabel("ESI Field")
    axes[0].set_xlim(-1.05, 1.05)
    axes[0].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[0].legend().set_visible(False)

    # Spearman Subplot
    sns.barplot(
        data=df_spearman,
        y='ESI Field',
        x='Spearman Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[1]
    )
    axes[1].set_title("Spearman Correlation Coefficient", fontsize=13, pad=10)
    axes[1].set_xlabel("Correlation Value")
    axes[1].set_ylabel("")
    axes[1].set_xlim(-1.05, 1.05)
    axes[1].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[1].legend().set_visible(False)

    # Add single common legend
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.97), ncol=2, fontsize=11)

    plt.suptitle(f"Correlation Comparison: {user_name} (All vs. Citable)", fontsize=15, y=1.03)
    plt.tight_layout()
    import os
    os.makedirs('figuras', exist_ok=True)
    fig_name_clean = user_name.replace(' ', '_').replace('/', '_').replace(':', '_').replace('(', '').replace(')', '')
    fig_filename = f"figuras/comparison_{fig_name_clean}.png"
    plt.savefig(fig_filename, bbox_inches='tight')
    global text
    text = text + f"<img src='{fig_filename}' alt='{user_name} Comparison'><br><br>\n"
    plt.show()

# %% [markdown]
# ## 1. AI vs DShareC Correlation Comparison
#
# This section compares the Pearson and Spearman correlations of **Activity Index (AI)** versus **DShareC**.
# This indicator measures how the proportion of publications (AI) relates to the document share in the citation distribution.

# %%
df_ai_dsharec = get_comparison_table('AI vs DShareC')
display_styled_table(df_ai_dsharec, 'Table 1: AI vs DShareC (All vs. Citable)')
plot_comparison(df_ai_dsharec, 'AI vs DShareC')
# Out:
# <style type="text/css">
# #T_cd4e2 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_cd4e2 td {
#   text-align: right;
# }
# #T_cd4e2 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_cd4e2_row0_col2, #T_cd4e2_row0_col5, #T_cd4e2_row1_col2, #T_cd4e2_row1_col5, #T_cd4e2_row2_col2, #T_cd4e2_row2_col5, #T_cd4e2_row3_col2, #T_cd4e2_row3_col5, #T_cd4e2_row4_col2, #T_cd4e2_row4_col5, #T_cd4e2_row5_col2, #T_cd4e2_row5_col5, #T_cd4e2_row6_col5, #T_cd4e2_row7_col5, #T_cd4e2_row8_col5, #T_cd4e2_row9_col5, #T_cd4e2_row10_col5, #T_cd4e2_row11_col2, #T_cd4e2_row11_col5, #T_cd4e2_row12_col5, #T_cd4e2_row13_col2, #T_cd4e2_row13_col5, #T_cd4e2_row14_col5, #T_cd4e2_row15_col5, #T_cd4e2_row16_col2, #T_cd4e2_row16_col5, #T_cd4e2_row17_col5, #T_cd4e2_row18_col2, #T_cd4e2_row18_col5, #T_cd4e2_row19_col2, #T_cd4e2_row19_col5, #T_cd4e2_row20_col2, #T_cd4e2_row20_col5, #T_cd4e2_row21_col2, #T_cd4e2_row21_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_cd4e2_row6_col2, #T_cd4e2_row7_col2, #T_cd4e2_row8_col2, #T_cd4e2_row9_col2, #T_cd4e2_row10_col2, #T_cd4e2_row12_col2, #T_cd4e2_row14_col2, #T_cd4e2_row15_col2, #T_cd4e2_row17_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_cd4e2" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 1: AI vs DShareC (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd4e2_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_cd4e2_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_cd4e2_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_cd4e2_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_cd4e2_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_cd4e2_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd4e2_level0_row0" class="row_heading level0 row0" >Agricultural Sciences</th>
#       <td id="T_cd4e2_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_cd4e2_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_cd4e2_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_cd4e2_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_cd4e2_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_cd4e2_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row1" class="row_heading level0 row1" >Biology & Biochemistry</th>
#       <td id="T_cd4e2_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_cd4e2_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_cd4e2_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_cd4e2_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_cd4e2_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_cd4e2_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row2" class="row_heading level0 row2" >Chemistry</th>
#       <td id="T_cd4e2_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_cd4e2_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_cd4e2_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_cd4e2_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_cd4e2_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_cd4e2_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row3" class="row_heading level0 row3" >Clinical Medicine</th>
#       <td id="T_cd4e2_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_cd4e2_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_cd4e2_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_cd4e2_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_cd4e2_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_cd4e2_row3_col5" class="data row3 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row4" class="row_heading level0 row4" >Computer Science</th>
#       <td id="T_cd4e2_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_cd4e2_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_cd4e2_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_cd4e2_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_cd4e2_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_cd4e2_row4_col5" class="data row4 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row5" class="row_heading level0 row5" >Economics & Business</th>
#       <td id="T_cd4e2_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_cd4e2_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_cd4e2_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_cd4e2_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_cd4e2_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_cd4e2_row5_col5" class="data row5 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row6" class="row_heading level0 row6" >Engineering</th>
#       <td id="T_cd4e2_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_cd4e2_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_cd4e2_row6_col2" class="data row6 col2" >-0.0000</td>
#       <td id="T_cd4e2_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_cd4e2_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_cd4e2_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row7" class="row_heading level0 row7" >Environment/Ecology</th>
#       <td id="T_cd4e2_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_cd4e2_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_cd4e2_row7_col2" class="data row7 col2" >-0.0000</td>
#       <td id="T_cd4e2_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_cd4e2_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_cd4e2_row7_col5" class="data row7 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row8" class="row_heading level0 row8" >Geosciences</th>
#       <td id="T_cd4e2_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_cd4e2_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_cd4e2_row8_col2" class="data row8 col2" >-0.0000</td>
#       <td id="T_cd4e2_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_cd4e2_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_cd4e2_row8_col5" class="data row8 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row9" class="row_heading level0 row9" >Immunology</th>
#       <td id="T_cd4e2_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_cd4e2_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_cd4e2_row9_col2" class="data row9 col2" >-0.0000</td>
#       <td id="T_cd4e2_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_cd4e2_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_cd4e2_row9_col5" class="data row9 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row10" class="row_heading level0 row10" >Materials Science</th>
#       <td id="T_cd4e2_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_cd4e2_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_cd4e2_row10_col2" class="data row10 col2" >-0.0000</td>
#       <td id="T_cd4e2_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_cd4e2_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_cd4e2_row10_col5" class="data row10 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cd4e2_level0_row11" class="row_heading level0 row11" >Mathematics</th>
#       <td id="T_cd4e2_row11_col0" class="data row11 col0" >1.0000</td>
#       <td id="T_cd4e2_row11_col1

# %% [markdown]
# ## 2. AI vs CShareD Correlation Comparison
#
# This section compares the correlations of **Activity Index (AI)** versus **CShareD**.

# %%
df_ai_cshared = get_comparison_table('AI vs CShareD')
display_styled_table(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'Table 2: AI vs CShareD (All vs. Citable)')
plot_comparison(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'AI vs CShareD')
# Out:
# <style type="text/css">
# #T_b5830 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_b5830 td {
#   text-align: right;
# }
# #T_b5830 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_b5830_row0_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b5830_row0_col5, #T_b5830_row2_col5, #T_b5830_row6_col5, #T_b5830_row9_col5, #T_b5830_row10_col5, #T_b5830_row11_col5, #T_b5830_row12_col5, #T_b5830_row13_col5, #T_b5830_row14_col5, #T_b5830_row15_col5, #T_b5830_row18_col5, #T_b5830_row19_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b5830_row1_col2, #T_b5830_row20_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b5830_row1_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b5830_row2_col2, #T_b5830_row3_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b5830_row3_col5, #T_b5830_row21_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b5830_row4_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_b5830_row4_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b5830_row5_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b5830_row5_col5, #T_b5830_row16_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b5830_row6_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_b5830_row7_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_b5830_row7_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b5830_row8_col2, #T_b5830_row14_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b5830_row8_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b5830_row9_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_b5830_row10_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_b5830_row11_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_b5830_row12_col2, #T_b5830_row16_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_b5830_row13_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b5830_row15_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b5830_row17_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b5830_row17_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b5830_row18_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_b5830_row19_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_b5830_row20_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b5830_row21_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# </style>
# <table id="T_b5830" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 2: AI vs CShareD (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5830_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_b5830_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_b5830_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_b5830_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_b5830_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_b5830_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5830_level0_row0" class="row_heading level0 row0" >Space Science</th>
#       <td id="T_b5830_row0_col0" class="data row0 col0" >0.0678</td>
#       <td id="T_b5830_row0_col1" class="data row0 col1" >0.0339</td>
#       <td id="T_b5830_row0_col2" class="data row0 col2" >-0.0339</td>
#       <td id="T_b5830_row0_col3" class="data row0 col3" >0.8423</td>
#       <td id="T_b5830_row0_col4" class="data row0 col4" >0.6290</td>
#       <td id="T_b5830_row0_col5" class="data row0 col5" >-0.2133</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row1" class="row_heading level0 row1" >Materials Science</th>
#       <td id="T_b5830_row1_col0" class="data row1 col0" >0.2558</td>
#       <td id="T_b5830_row1_col1" class="data row1 col1" >0.2436</td>
#       <td id="T_b5830_row1_col2" class="data row1 col2" >-0.0121</td>
#       <td id="T_b5830_row1_col3" class="data row1 col3" >0.7929</td>
#       <td id="T_b5830_row1_col4" class="data row1 col4" >0.7253</td>
#       <td id="T_b5830_row1_col5" class="data row1 col5" >-0.0676</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row2" class="row_heading level0 row2" >Computer Science</th>
#       <td id="T_b5830_row2_col0" class="data row2 col0" >0.1800</td>
#       <td id="T_b5830_row2_col1" class="data row2 col1" >0.1433</td>
#       <td id="T_b5830_row2_col2" class="data row2 col2" >-0.0366</td>
#       <td id="T_b5830_row2_col3" class="data row2 col3" >0.7863</td>
#       <td id="T_b5830_row2_col4" class="data row2 col4" >0.5782</td>
#       <td id="T_b5830_row2_col5" class="data row2 col5" >-0.2081</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row3" class="row_heading level0 row3" >Physics</th>
#       <td id="T_b5830_row3_col0" class="data row3 col0" >0.0900</td>
#       <td id="T_b5830_row3_col1" class="data row3 col1" >0.0532</td>
#       <td id="T_b5830_row3_col2" class="data row3 col2" >-0.0368</td>
#       <td id="T_b5830_row3_col3" class="data row3 col3" >0.7632</td>
#       <td id="T_b5830_row3_col4" class="data row3 col4" >0.6377</td>
#       <td id="T_b5830_row3_col5" class="data row3 col5" >-0.1255</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row4" class="row_heading level0 row4" >Chemistry</th>
#       <td id="T_b5830_row4_col0" class="data row4 col0" >0.1970</td>
#       <td id="T_b5830_row4_col1" class="data row4 col1" >0.1776</td>
#       <td id="T_b5830_row4_col2" class="data row4 col2" >-0.0194</td>
#       <td id="T_b5830_row4_col3" class="data row4 col3" >0.7400</td>
#       <td id="T_b5830_row4_col4" class="data row4 col4" >0.6415</td>
#       <td id="T_b5830_row4_col5" class="data row4 col5" >-0.0985</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row5" class="row_heading level0 row5" >Engineering</th>
#       <td id="T_b5830_row5_col0" class="data row5 col0" >0.1913</td>
#       <td id="T_b5830_row5_col1" class="data row5 col1" >0.1769</td>
#       <td id="T_b5830_row5_col2" class="data row5 col2" >-0.0144</td>
#       <td id="T_b5830_row5_col3" class="data row5 col3" >0.6769</td>
#       <td id="T_b5830_row5_col4" class="data row5 col4" >0.5807</td>
#       <td id="T_b5830_row5_col5" class="data row5 col5" >-0.0962</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row6" class="row_heading level0 row6" >Mathematics</th>
#       <td id="T_b5830_row6_col0" class="data row6 col0" >0.0583</td>
#       <td id="T_b5830_row6_col1" class="data row6 col1" >0.0048</td>
#       <td id="T_b5830_row6_col2" class="data row6 col2" >-0.0536</td>
#       <td id="T_b5830_row6_col3" class="data row6 col3" >0.6702</td>
#       <td id="T_b5830_row6_col4" class="data row6 col4" >0.4142</td>
#       <td id="T_b5830_row6_col5" class="data row6 col5" >-0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row7" class="row_heading level0 row7" >Biology & Biochemistry</th>
#       <td id="T_b5830_row7_col0" class="data row7 col0" >0.1792</td>
#       <td id="T_b5830_row7_col1" class="data row7 col1" >0.1395</td>
#       <td id="T_b5830_row7_col2" class="data row7 col2" >-0.0397</td>
#       <td id="T_b5830_row7_col3" class="data row7 col3" >0.6623</td>
#       <td id="T_b5830_row7_col4" class="data row7 col4" >0.4862</td>
#       <td id="T_b5830_row7_col5" class="data row7 col5" >-0.1761</td>
#     </tr>
#     <tr>
#       <th id="T_b5830_level0_row8" class="row_heading level0 row8" >Economics & Business</th>
#       <td id="T_b5830_row8_col0" class="data row8 col0" >0.1198</td>
#       <td id="T_b5830_row8_col1" class="data row8 col1" >0.0902</td>
#       <td id="T_b5830_row8_col2" class="data row8 col2" >-0.0296</td>
#       <td id="T_b5830_row8_col3" class="data row8 col3" >0.6516</td>
#       <td id="T_b5830_row8_col4" class="data row8 col4" >0.4565</td>
#       <td id="T_b5830_row8_col5" class="data row8 col5" >-0.1951</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## 3. F-Measure vs DShareC (ShareC) Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **DShareC**.

# %%
df_f_dsharec = get_comparison_table('F-Measure vs DShareC')
display_styled_table(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'Table 3: F-Measure vs DShareC (All vs. Citable)')
plot_comparison(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'F-Measure vs DShareC (ShareC)')
# Out:
# <style type="text/css">
# #T_5415c th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_5415c td {
#   text-align: right;
# }
# #T_5415c caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_5415c_row0_col2, #T_5415c_row1_col5, #T_5415c_row16_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_5415c_row0_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_5415c_row1_col2, #T_5415c_row20_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_5415c_row2_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_5415c_row2_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_5415c_row3_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_5415c_row3_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5415c_row4_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5415c_row4_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5415c_row5_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5415c_row5_col5, #T_5415c_row9_col5, #T_5415c_row10_col5, #T_5415c_row11_col5, #T_5415c_row12_col2, #T_5415c_row12_col5, #T_5415c_row13_col5, #T_5415c_row14_col5, #T_5415c_row15_col5, #T_5415c_row16_col5, #T_5415c_row19_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5415c_row6_col2, #T_5415c_row11_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5415c_row6_col5, #T_5415c_row18_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_5415c_row7_col2, #T_5415c_row14_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_5415c_row7_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5415c_row8_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5415c_row8_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_5415c_row9_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_5415c_row10_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_5415c_row13_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_5415c_row15_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_5415c_row17_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_5415c_row17_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5415c_row18_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_5415c_row19_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5415c_row20_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5415c_row21_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_5415c_row21_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5415c" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 3: F-Measure vs DShareC (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5415c_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_5415c_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_5415c_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_5415c_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_5415c_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_5415c_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5415c_level0_row0" class="row_heading level0 row0" >Space Science</th>
#       <td id="T_5415c_row0_col0" class="data row0 col0" >0.1873</td>
#       <td id="T_5415c_row0_col1" class="data row0 col1" >0.1232</td>
#       <td id="T_5415c_row0_col2" class="data row0 col2" >-0.0641</td>
#       <td id="T_5415c_row0_col3" class="data row0 col3" >0.8797</td>
#       <td id="T_5415c_row0_col4" class="data row0 col4" >0.7129</td>
#       <td id="T_5415c_row0_col5" class="data row0 col5" >-0.1668</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row1" class="row_heading level0 row1" >Materials Science</th>
#       <td id="T_5415c_row1_col0" class="data row1 col0" >0.4268</td>
#       <td id="T_5415c_row1_col1" class="data row1 col1" >0.4029</td>
#       <td id="T_5415c_row1_col2" class="data row1 col2" >-0.0239</td>
#       <td id="T_5415c_row1_col3" class="data row1 col3" >0.8042</td>
#       <td id="T_5415c_row1_col4" class="data row1 col4" >0.7396</td>
#       <td id="T_5415c_row1_col5" class="data row1 col5" >-0.0646</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row2" class="row_heading level0 row2" >Computer Science</th>
#       <td id="T_5415c_row2_col0" class="data row2 col0" >0.4363</td>
#       <td id="T_5415c_row2_col1" class="data row2 col1" >0.3555</td>
#       <td id="T_5415c_row2_col2" class="data row2 col2" >-0.0808</td>
#       <td id="T_5415c_row2_col3" class="data row2 col3" >0.8017</td>
#       <td id="T_5415c_row2_col4" class="data row2 col4" >0.6075</td>
#       <td id="T_5415c_row2_col5" class="data row2 col5" >-0.1942</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row3" class="row_heading level0 row3" >Physics</th>
#       <td id="T_5415c_row3_col0" class="data row3 col0" >0.2336</td>
#       <td id="T_5415c_row3_col1" class="data row3 col1" >0.1641</td>
#       <td id="T_5415c_row3_col2" class="data row3 col2" >-0.0695</td>
#       <td id="T_5415c_row3_col3" class="data row3 col3" >0.7729</td>
#       <td id="T_5415c_row3_col4" class="data row3 col4" >0.6511</td>
#       <td id="T_5415c_row3_col5" class="data row3 col5" >-0.1218</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row4" class="row_heading level0 row4" >Chemistry</th>
#       <td id="T_5415c_row4_col0" class="data row4 col0" >0.3596</td>
#       <td id="T_5415c_row4_col1" class="data row4 col1" >0.3248</td>
#       <td id="T_5415c_row4_col2" class="data row4 col2" >-0.0348</td>
#       <td id="T_5415c_row4_col3" class="data row4 col3" >0.7465</td>
#       <td id="T_5415c_row4_col4" class="data row4 col4" >0.6499</td>
#       <td id="T_5415c_row4_col5" class="data row4 col5" >-0.0966</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row5" class="row_heading level0 row5" >Mathematics</th>
#       <td id="T_5415c_row5_col0" class="data row5 col0" >0.2593</td>
#       <td id="T_5415c_row5_col1" class="data row5 col1" >0.1527</td>
#       <td id="T_5415c_row5_col2" class="data row5 col2" >-0.1066</td>
#       <td id="T_5415c_row5_col3" class="data row5 col3" >0.6940</td>
#       <td id="T_5415c_row5_col4" class="data row5 col4" >0.4524</td>
#       <td id="T_5415c_row5_col5" class="data row5 col5" >-0.2416</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row6" class="row_heading level0 row6" >Engineering</th>
#       <td id="T_5415c_row6_col0" class="data row6 col0" >0.2859</td>
#       <td id="T_5415c_row6_col1" class="data row6 col1" >0.2586</td>
#       <td id="T_5415c_row6_col2" class="data row6 col2" >-0.0273</td>
#       <td id="T_5415c_row6_col3" class="data row6 col3" >0.6860</td>
#       <td id="T_5415c_row6_col4" class="data row6 col4" >0.5917</td>
#       <td id="T_5415c_row6_col5" class="data row6 col5" >-0.0943</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row7" class="row_heading level0 row7" >Economics & Business</th>
#       <td id="T_5415c_row7_col0" class="data row7 col0" >0.3328</td>
#       <td id="T_5415c_row7_col1" class="data row7 col1" >0.2668</td>
#       <td id="T_5415c_row7_col2" class="data row7 col2" >-0.0660</td>
#       <td id="T_5415c_row7_col3" class="data row7 col3" >0.6820</td>
#       <td id="T_5415c_row7_col4" class="data row7 col4" >0.5039</td>
#       <td id="T_5415c_row7_col5" class="data row7 col5" >-0.1781</td>
#     </tr>
#     <tr>
#       <th id="T_5415c_level0_row8" class="row_heading level0 row8" >Biology & Biochemistry</th>
#       <td id="T_5415c_row8_col0" class="data row8 col0" >0.3452</td>
#       <td id="T_5415c_row8_col1" class="data row8 col1" >0.2767</td>
#       <td id="T_5415c_row8_col2" class="data row8 col2" >-0.0686</td>
#       <td id="T_5415c_row8_col3" class="data row8 col3" >0.6734</td>
#       <td id="T_5415c_row8_col4" class="data row8 col4" >0.5047</td>
#       <td id="T_5415c_row8_col5" c

# %% [markdown]
# ## 4. F-Measure vs CShareD Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **CShareD**.

# %%
df_f_cshared = get_comparison_table('F-Measure vs CShareD')
display_styled_table(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'Table 4: F-Measure vs CShareD (All vs. Citable)')
plot_comparison(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'F-Measure vs CShareD')
# Out:
# <style type="text/css">
# #T_49a0a th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_49a0a td {
#   text-align: right;
# }
# #T_49a0a caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_49a0a_row0_col2, #T_49a0a_row16_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_49a0a_row0_col5, #T_49a0a_row1_col2, #T_49a0a_row1_col5, #T_49a0a_row3_col2, #T_49a0a_row3_col5, #T_49a0a_row4_col5, #T_49a0a_row5_col5, #T_49a0a_row7_col5, #T_49a0a_row8_col2, #T_49a0a_row8_col5, #T_49a0a_row9_col5, #T_49a0a_row10_col2, #T_49a0a_row10_col5, #T_49a0a_row11_col5, #T_49a0a_row12_col5, #T_49a0a_row13_col5, #T_49a0a_row14_col5, #T_49a0a_row15_col5, #T_49a0a_row16_col5, #T_49a0a_row17_col5, #T_49a0a_row18_col5, #T_49a0a_row19_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_49a0a_row2_col2, #T_49a0a_row2_col5, #T_49a0a_row6_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_49a0a_row4_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_49a0a_row5_col2, #T_49a0a_row13_col2, #T_49a0a_row14_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_49a0a_row6_col2, #T_49a0a_row15_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_49a0a_row7_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_49a0a_row9_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_49a0a_row11_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_49a0a_row12_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_49a0a_row17_col2, #T_49a0a_row19_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_49a0a_row18_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_49a0a_row20_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_49a0a_row20_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_49a0a_row21_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_49a0a_row21_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# </style>
# <table id="T_49a0a" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 4: F-Measure vs CShareD (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49a0a_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_49a0a_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_49a0a_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_49a0a_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_49a0a_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_49a0a_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49a0a_level0_row0" class="row_heading level0 row0" >Clinical Medicine</th>
#       <td id="T_49a0a_row0_col0" class="data row0 col0" >0.9688</td>
#       <td id="T_49a0a_row0_col1" class="data row0 col1" >0.9416</td>
#       <td id="T_49a0a_row0_col2" class="data row0 col2" >-0.0272</td>
#       <td id="T_49a0a_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_49a0a_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_49a0a_row0_col5" class="data row0 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row1" class="row_heading level0 row1" >Chemistry</th>
#       <td id="T_49a0a_row1_col0" class="data row1 col0" >0.8707</td>
#       <td id="T_49a0a_row1_col1" class="data row1 col1" >0.8705</td>
#       <td id="T_49a0a_row1_col2" class="data row1 col2" >-0.0002</td>
#       <td id="T_49a0a_row1_col3" class="data row1 col3" >0.9997</td>
#       <td id="T_49a0a_row1_col4" class="data row1 col4" >0.9997</td>
#       <td id="T_49a0a_row1_col5" class="data row1 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row2" class="row_heading level0 row2" >Environment/Ecology</th>
#       <td id="T_49a0a_row2_col0" class="data row2 col0" >0.7327</td>
#       <td id="T_49a0a_row2_col1" class="data row2 col1" >0.7334</td>
#       <td id="T_49a0a_row2_col2" class="data row2 col2" >0.0007</td>
#       <td id="T_49a0a_row2_col3" class="data row2 col3" >0.9997</td>
#       <td id="T_49a0a_row2_col4" class="data row2 col4" >0.9997</td>
#       <td id="T_49a0a_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row3" class="row_heading level0 row3" >Engineering</th>
#       <td id="T_49a0a_row3_col0" class="data row3 col0" >0.9338</td>
#       <td id="T_49a0a_row3_col1" class="data row3 col1" >0.9333</td>
#       <td id="T_49a0a_row3_col2" class="data row3 col2" >-0.0005</td>
#       <td id="T_49a0a_row3_col3" class="data row3 col3" >0.9997</td>
#       <td id="T_49a0a_row3_col4" class="data row3 col4" >0.9997</td>
#       <td id="T_49a0a_row3_col5" class="data row3 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row4" class="row_heading level0 row4" >Biology & Biochemistry</th>
#       <td id="T_49a0a_row4_col0" class="data row4 col0" >0.7790</td>
#       <td id="T_49a0a_row4_col1" class="data row4 col1" >0.7573</td>
#       <td id="T_49a0a_row4_col2" class="data row4 col2" >-0.0218</td>
#       <td id="T_49a0a_row4_col3" class="data row4 col3" >0.9997</td>
#       <td id="T_49a0a_row4_col4" class="data row4 col4" >0.9995</td>
#       <td id="T_49a0a_row4_col5" class="data row4 col5" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row5" class="row_heading level0 row5" >Plant & Animal Science</th>
#       <td id="T_49a0a_row5_col0" class="data row5 col0" >0.7322</td>
#       <td id="T_49a0a_row5_col1" class="data row5 col1" >0.7305</td>
#       <td id="T_49a0a_row5_col2" class="data row5 col2" >-0.0016</td>
#       <td id="T_49a0a_row5_col3" class="data row5 col3" >0.9997</td>
#       <td id="T_49a0a_row5_col4" class="data row5 col4" >0.9996</td>
#       <td id="T_49a0a_row5_col5" class="data row5 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row6" class="row_heading level0 row6" >Social Sciences, general</th>
#       <td id="T_49a0a_row6_col0" class="data row6 col0" >0.8736</td>
#       <td id="T_49a0a_row6_col1" class="data row6 col1" >0.8770</td>
#       <td id="T_49a0a_row6_col2" class="data row6 col2" >0.0034</td>
#       <td id="T_49a0a_row6_col3" class="data row6 col3" >0.9996</td>
#       <td id="T_49a0a_row6_col4" class="data row6 col4" >0.9996</td>
#       <td id="T_49a0a_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row7" class="row_heading level0 row7" >Geosciences</th>
#       <td id="T_49a0a_row7_col0" class="data row7 col0" >0.7216</td>
#       <td id="T_49a0a_row7_col1" class="data row7 col1" >0.7172</td>
#       <td id="T_49a0a_row7_col2" class="data row7 col2" >-0.0044</td>
#       <td id="T_49a0a_row7_col3" class="data row7 col3" >0.9995</td>
#       <td id="T_49a0a_row7_col4" class="data row7 col4" >0.9995</td>
#       <td id="T_49a0a_row7_col5" class="data row7 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row8" class="row_heading level0 row8" >Physics</th>
#       <td id="T_49a0a_row8_col0" class="data row8 col0" >0.7602</td>
#       <td id="T_49a0a_row8_col1" class="data row8 col1" >0.7602</td>
#       <td id="T_49a0a_row8_col2" class="data row8 col2" >-0.0000</td>
#       <td id="T_49a0a_row8_col3" class="data row8 col3" >0.9995</td>
#       <td id="T_49a0a_row8_col4" class="data row8 col4" >0.9993</td>
#       <td id="T_49a0a_row8_col5" class="data row8 col5" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_49a0a_level0_row9" class="row_heading level0 row9" >Pharmacology & Toxicology</th>
#       <td id="T_49a0a_row9_col0" class="data row9 col0" >0.7082</td>
#       <td id="T_49a0a_row9_col1" class="data row9 col1" >0.6748</td>
#       <td id="T_49a0a_row9_col2" class="data row9 col2" >-0.0335</td>
#       <td id="T_49a0a_row9_col3" class="data row9 col3" >0.9994</td>
#       <td id="T_49a0a_row9_col4" class="data row9 col4" >0.9991</td>
#       <td id="T_49a0a_row9_col5" class="data row9 col5" >-0.0002</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## 5. Summary Statistics and Overall Analysis (Absolute Discrepancies)
#
# To synthesize the comparison, let's look at the summary statistics of the **absolute differences** across all 22 ESI fields for each of the four indicator pairs.
#
# Using absolute values is essential because it measures the magnitude of the discrepancy (change) regardless of whether the correlation went up or down. For example, a large negative change like -0.76708 represents a major discrepancy of 0.76708 in absolute terms. Computing statistics on signed differences can cause positive and negative changes to cancel each other out, hiding the true extent of the changes.

# %%
summary_data = []
pairs_mapping = {
    'AI vs DShareC': 'AI vs DShareC',
    'AI vs CShareD': 'AI vs CShareD',
    'F-Measure vs DShareC': 'F-Measure vs DShareC',
    'F-Measure vs CShareD': 'F-Measure vs CShareD'
}

for user_name, csv_name in pairs_mapping.items():
    df_p = get_comparison_table(csv_name)
    pearson_abs = df_p['Pearson Diff (Citable - All)'].abs()
    spearman_abs = df_p['Spearman Diff (Citable - All)'].abs()
    summary_data.append({
        'Indicator Pair': user_name,
        'Mean Abs Pearson Diff': pearson_abs.mean(),
        'Median Abs Pearson Diff': pearson_abs.median(),
        'Max Abs Pearson Diff': pearson_abs.max(),
        'Min Abs Pearson Diff': pearson_abs.min(),
        'Mean Abs Spearman Diff': spearman_abs.mean(),
        'Median Abs Spearman Diff': spearman_abs.median(),
        'Max Abs Spearman Diff': spearman_abs.max(),
        'Min Abs Spearman Diff': spearman_abs.min()
    })

df_summary = pd.DataFrame(summary_data).set_index('Indicator Pair')

styled_summary = df_summary.style.format("{:.5f}")\
    .background_gradient(cmap="Reds", vmin=0.0, vmax=0.3)\
    .set_caption("<b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|Citable - All|)</b>")\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#2c3e50'), ('color', 'white'), ('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('text-align', 'right')]},
        {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
    ])
display(styled_summary)
global text
text = text + "<h2>Overall Comparison Summary</h2>" + styled_summary.to_html() + "<br><br>"
# Out:
# <style type="text/css">
# #T_a515c th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_a515c td {
#   text-align: right;
# }
# #T_a515c caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_a515c_row0_col0, #T_a515c_row0_col1, #T_a515c_row0_col2, #T_a515c_row0_col3, #T_a515c_row0_col4, #T_a515c_row0_col5, #T_a515c_row0_col6, #T_a515c_row0_col7, #T_a515c_row3_col3, #T_a515c_row3_col5, #T_a515c_row3_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_a515c_row1_col0 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_a515c_row1_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_a515c_row1_col2 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_a515c_row1_col3 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_a515c_row1_col4 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_a515c_row1_col5 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_a515c_row1_col6, #T_a515c_row2_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a515c_row1_col7 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_a515c_row2_col0 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_a515c_row2_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_a515c_row2_col2 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_a515c_row2_col3 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_a515c_row2_col4 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_a515c_row2_col5 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_a515c_row2_col7 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_a515c_row3_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_a515c_row3_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_a515c_row3_col2 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_a515c_row3_col4 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_a515c_row3_col6 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# </style>
# <table id="T_a515c" class="dataframe">
#   <caption><b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|Citable - All|)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a515c_level0_col0" class="col_heading level0 col0" >Mean Abs Pearson Diff</th>
#       <th id="T_a515c_level0_col1" class="col_heading level0 col1" >Median Abs Pearson Diff</th>
#       <th id="T_a515c_level0_col2" class="col_heading level0 col2" >Max Abs Pearson Diff</th>
#       <th id="T_a515c_level0_col3" class="col_heading level0 col3" >Min Abs Pearson Diff</th>
#       <th id="T_a515c_level0_col4" class="col_heading level0 col4" >Mean Abs Spearman Diff</th>
#       <th id="T_a515c_level0_col5" class="col_heading level0 col5" >Median Abs Spearman Diff</th>
#       <th id="T_a515c_level0_col6" class="col_heading level0 col6" >Max Abs Spearman Diff</th>
#       <th id="T_a515c_level0_col7" class="col_heading level0 col7" >Min Abs Spearman Diff</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator Pair</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a515c_level0_row0" class="row_heading level0 row0" >AI vs DShareC</th>
#       <td id="T_a515c_row0_col0" class="data row0 col0" >0.00000</td>
#       <td id="T_a515c_row0_col1" class="data row0 col1" >0.00000</td>
#       <td id="T_a515c_row0_col2" class="data row0 col2" >0.00000</td>
#       <td id="T_a515c_row0_col3" class="data row0 col3" >0.00000</td>
#       <td id="T_a515c_row0_col4" class="data row0 col4" >0.00000</td>
#       <td id="T_a515c_row0_col5" class="data row0 col5" >0.00000</td>
#       <td id="T_a515c_row0_col6" class="data row0 col6" >0.00000</td>
#       <td id="T_a515c_row0_col7" class="data row0 col7" >0.00000</td>
#     </tr>
#     <tr>
#       <th id="T_a515c_level0_row1" class="row_heading level0 row1" >AI vs CShareD</th>
#       <td id="T_a515c_row1_col0" class="data row1 col0" >0.02992</td>
#       <td id="T_a515c_row1_col1" class="data row1 col1" >0.02705</td>
#       <td id="T_a515c_row1_col2" class="data row1 col2" >0.09208</td>
#       <td id="T_a515c_row1_col3" class="data row1 col3" >0.00361</td>
#       <td id="T_a515c_row1_col4" class="data row1 col4" >0.21868</td>
#       <td id="T_a515c_row1_col5" class="data row1 col5" >0.21071</td>
#       <td id="T_a515c_row1_col6" class="data row1 col6" >0.76708</td>
#       <td id="T_a515c_row1_col7" class="data row1 col7" >0.06757</td>
#     </tr>
#     <tr>
#       <th id="T_a515c_level0_row2" class="row_heading level0 row2" >F-Measure vs DShareC</th>
#       <td id="T_a515c_row2_col0" class="data row2 col0" >0.06096</td>
#       <td id="T_a515c_row2_col1" class="data row2 col1" >0.05552</td>
#       <td id="T_a515c_row2_col2" class="data row2 col2" >0.23475</td>
#       <td id="T_a515c_row2_col3" class="data row2 col3" >0.00561</td>
#       <td id="T_a515c_row2_col4" class="data row2 col4" >0.20108</td>
#       <td id="T_a515c_row2_col5" class="data row2 col5" >0.18611</td>
#       <td id="T_a515c_row2_col6" class="data row2 col6" >0.57543</td>
#       <td id="T_a515c_row2_col7" class="data row2 col7" >0.06460</td>
#     </tr>
#     <tr>
#       <th id="T_a515c_level0_row3" class="row_heading level0 row3" >F-Measure vs CShareD</th>
#       <td id="T_a515c_row3_col0" class="data row3 col0" >0.01415</td>
#       <td id="T_a515c_row3_col1" class="data row3 col1" >0.00725</td>
#       <td id="T_a515c_row3_col2" class="data row3 col2" >0.08403</td>
#       <td id="T_a515c_row3_col3" class="data row3 col3" >0.00005</td>
#       <td id="T_a515c_row3_col4" class="data row3 col4" >0.00322</td>
#       <td id="T_a515c_row3_col5" class="data row3 col5" >0.00023</td>
#       <td id="T_a515c_row3_col6" class="data row3 col6" >0.05648</td>
#       <td id="T_a515c_row3_col7" class="data row3 col7" >0.00001</td>
#     </tr>
#   </tbody>
# </table>

# %%
global text
text = text + "</body></html>"
with open("manuscriptFiguresAndTables.html", "w", encoding="utf-8") as f:
    f.write(text)
print("Saved report to manuscriptFiguresAndTables.html")
