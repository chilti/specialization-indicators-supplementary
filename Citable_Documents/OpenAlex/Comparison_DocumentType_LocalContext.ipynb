# %% [markdown]
# # Comparison of Local Context Correlations: All Documents vs. Citable Documents
#
# This notebook performs a systematic comparison between the correlations calculated for **All Documents** and **Citable Documents** in the Local Context across different OpenAlex Topics.

# %%
#Montar mi google drive para poder usar los archivos
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/LocalContext/"
# !ls
# Out:
# /content/gdrive/.shortcut-targets-by-id/0B5aSrRJgnViLfm9LWl9TY21TWm5wSU0zbkgzc2YyeEp3RzJMaEJOR2FWbFkxVEZYTjNQd1E/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/LocalContext
# 'All_vs_Citable Documents.html'
#  figuras
#  ManuscriptActivityIndexFmeasure_ESI_LocalContext.ipynb
#  manuscriptFiguresAndTables.html
#  pearson_correlation_AI_FMeasure.csv
#  scatterplots
#  scatterplots.html
#  Spearman_correlation_AI_FMeasure.csv

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set plotting style
sns.set_theme(style="whitegrid")
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['DejaVu Sans', 'Arial', 'Helvetica'],
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titlesize': 14,
    'figure.titleweight': 'bold'
})


# Initialize HTML report container
text = """
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>Comparison Analysis Report</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; color: #2c3e50; }
        h1, h2, h3 { color: #2c3e50; }
        table { border-collapse: collapse; width: 100%; margin-bottom: 20px; }
        th, td { border: 1px solid #bdc3c7; padding: 8px; text-align: left; }
        th { background-color: #f4f6f7; font-weight: bold; }
        img { max-width: 100%; height: auto; display: block; margin: 20px 0; }
    </style>
</head>
<body>
<h1>Comparison Analysis Report (All vs. Citable Documents)</h1>
"""

# %%
# Define paths to the CSV files
paths = {
    'all_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/All_Documents/OpenAlex/LocalContext/pearson_correlation_AI_FMeasure.csv',
    'all_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/All_Documents/OpenAlex/LocalContext/Spearman_correlation_AI_FMeasure.csv',
    'citable_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/LocalContext/pearson_correlation_AI_FMeasure.csv',
    'citable_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/LocalContext/Spearman_correlation_AI_FMeasure.csv'
}

# Load files
dfs = {}
for name, path in paths.items():
    if not os.path.exists(path):
        # Try relative paths as fallback
        if '2026' in path:
            rel_path = f'Global Context/{os.path.basename(path)}'
        else:
            rel_path = f'../../ManuscriptExperiments/Global Context/{os.path.basename(path)}'
        if os.path.exists(rel_path):
            path = rel_path

    dfs[name] = pd.read_csv(path, index_col=0)
    print(f"Successfully loaded {name} (Shape: {dfs[name].shape})")
# Out:
# Successfully loaded all_pearson (Shape: (247, 11))
# Successfully loaded all_spearman (Shape: (247, 10))
# Successfully loaded citable_pearson (Shape: (247, 11))
# Successfully loaded citable_spearman (Shape: (247, 10))

# %%
def get_comparison_table(col_name):
    """
    Creates a side-by-side comparison table for a specific correlation column.
    """
    # Base index of OpenAlex Fields from the Pearson All dataset
    index_ref = dfs['all_pearson'].index

    df_comp = pd.DataFrame(index=index_ref)

    # Pearson
    df_comp['Pearson (All)'] = dfs['all_pearson'][col_name]
    df_comp['Pearson (Citable)'] = dfs['citable_pearson'][col_name]
    df_comp['Pearson Diff (Citable - All)'] = df_comp['Pearson (Citable)'] - df_comp['Pearson (All)']

    # Spearman (aligning indices)
    df_comp['Spearman (All)'] = df_comp.index.map(dfs['all_spearman'][col_name])
    df_comp['Spearman (Citable)'] = df_comp.index.map(dfs['citable_spearman'][col_name])
    df_comp['Spearman Diff (Citable - All)'] = df_comp['Spearman (Citable)'] - df_comp['Spearman (All)']

    # Sort OpenAlex Fields alphabetically
    df_comp = df_comp.sort_index()
    return df_comp

def display_styled_table(df, title):
    """
    Applies advanced pandas styler to color-code difference columns and display.
    """
    styled = df.style.format("{:.4f}")\
        .background_gradient(cmap="coolwarm", subset=["Pearson Diff (Citable - All)", "Spearman Diff (Citable - All)"], vmin=-0.2, vmax=0.2)\
        .set_caption(f"<b style='font-size: 14px;'>{title}</b>")\
        .set_table_styles([
            {'selector': 'th', 'props': [('background-color', '#f4f6f7'), ('color', '#2c3e50'), ('font-weight', 'bold'), ('text-align', 'center')]},
            {'selector': 'td', 'props': [('text-align', 'right')]},
            {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
        ])
    display(styled)
    global text
    text = text + f"<h2>{title}</h2>" + styled.to_html() + "<br><br>"

def plot_comparison(df, user_name):
    """
    Generates side-by-side horizontal bar plots to visualize the differences in correlations.
    """
    # Prepare Pearson data for Seaborn
    df_pearson = pd.DataFrame({
        'OpenAlex Field': df.index,
        'All Documents': df['Pearson (All)'].values,
        'Citable Documents': df['Pearson (Citable)'].values
    }).melt(id_vars='OpenAlex Field', var_name='Dataset', value_name='Pearson Correlation')

    # Prepare Spearman data for Seaborn
    df_spearman = pd.DataFrame({
        'OpenAlex Field': df.index,
        'All Documents': df['Spearman (All)'].values,
        'Citable Documents': df['Spearman (Citable)'].values
    }).melt(id_vars='OpenAlex Field', var_name='Dataset', value_name='Spearman Correlation')

    fig, axes = plt.subplots(1, 2, figsize=(16, 49), sharey=True)

    # Harmonious colors: Cool Blue for All, Warm Coral for Citable
    colors = {'All Documents': '#2b7bba', 'Citable Documents': '#e76f51'}

    # Pearson Subplot
    sns.barplot(
        data=df_pearson,
        y='OpenAlex Field',
        x='Pearson Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[0]
    )
    axes[0].set_title("Pearson Correlation Coefficient", fontsize=13, pad=10)
    axes[0].set_xlabel("Correlation Value")
    axes[0].set_ylabel("OpenAlex Field")
    axes[0].set_xlim(-1.05, 1.05)
    axes[0].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[0].legend().set_visible(False)

    # Spearman Subplot
    sns.barplot(
        data=df_spearman,
        y='OpenAlex Field',
        x='Spearman Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[1]
    )
    axes[1].set_title("Spearman Correlation Coefficient", fontsize=13, pad=10)
    axes[1].set_xlabel("Correlation Value")
    axes[1].set_ylabel("")
    axes[1].set_xlim(-1.05, 1.05)
    axes[1].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[1].legend().set_visible(False)

    # Add single common legend
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.97), ncol=2, fontsize=11)

    plt.suptitle(f"Correlation Comparison: {user_name} (All vs. Citable)", fontsize=15, y=1.03)
    plt.tight_layout()
    import os
    os.makedirs('figuras', exist_ok=True)
    fig_name_clean = user_name.replace(' ', '_').replace('/', '_').replace(':', '_').replace('(', '').replace(')', '')
    fig_filename = f"figuras/comparison_{fig_name_clean}.png"
    plt.savefig(fig_filename, bbox_inches='tight')
    global text
    text = text + f"<img src='{fig_filename}' alt='{user_name} Comparison'><br><br>\n"
    plt.show()

# %% [markdown]
# ## 1. AI vs DShareC Correlation Comparison
#
# This section compares the Pearson and Spearman correlations of **Activity Index (AI)** versus **DShareC**.
# This indicator measures how the proportion of publications (AI) relates to the document share in the citation distribution.

# %%
df_ai_dsharec = get_comparison_table('AI vs DShareC')
display_styled_table(df_ai_dsharec.sort_values('Spearman (All)', ascending=False), 'Table 1: AI vs DShareC (All vs. Citable)')
plot_comparison(df_ai_dsharec.sort_values('Spearman (All)', ascending=False), 'AI vs DShareC')
# Out:
# <style type="text/css">
# #T_9b115 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_9b115 td {
#   text-align: right;
# }
# #T_9b115 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_9b115_row0_col2, #T_9b115_row13_col2, #T_9b115_row17_col5, #T_9b115_row34_col2, #T_9b115_row121_col2, #T_9b115_row140_col2, #T_9b115_row169_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_9b115_row0_col5, #T_9b115_row1_col5, #T_9b115_row2_col5, #T_9b115_row11_col5, #T_9b115_row12_col5, #T_9b115_row22_col5, #T_9b115_row28_col5, #T_9b115_row31_col5, #T_9b115_row56_col2, #T_9b115_row62_col2, #T_9b115_row64_col5, #T_9b115_row66_col5, #T_9b115_row70_col5, #T_9b115_row79_col5, #T_9b115_row109_col5, #T_9b115_row117_col2, #T_9b115_row117_col5, #T_9b115_row133_col5, #T_9b115_row168_col5, #T_9b115_row184_col2, #T_9b115_row184_col5, #T_9b115_row187_col5, #T_9b115_row217_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9b115_row1_col2, #T_9b115_row7_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_9b115_row2_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9b115_row3_col2, #T_9b115_row50_col5, #T_9b115_row125_col5, #T_9b115_row133_col2, #T_9b115_row154_col2, #T_9b115_row190_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9b115_row3_col5, #T_9b115_row25_col2, #T_9b115_row48_col5, #T_9b115_row79_col2, #T_9b115_row137_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_9b115_row4_col2, #T_9b115_row98_col5, #T_9b115_row202_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_9b115_row4_col5, #T_9b115_row15_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_9b115_row5_col2, #T_9b115_row19_col2, #T_9b115_row129_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_9b115_row5_col5, #T_9b115_row43_col5, #T_9b115_row49_col5, #T_9b115_row69_col5, #T_9b115_row95_col2, #T_9b115_row108_col5, #T_9b115_row119_col2, #T_9b115_row200_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_
col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_9b115_row33_col2, #T_9b115_row51_col5, #T_9b115_row52_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_9b115_row33_col5, #T_9b115_row124_col5, #T_9b115_row150_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_9b115_row34_col5, #T_9b115_row43_col2, #T_9b115_row67_col2, #T_9b115_row97_col2, #T_9b115_row137_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_9b115_row35_col2, #T_9b115_row106_col5, #T_9b115_row111_col5, #T_9b115_row112_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_9b115_row36_col2, #T_9b115_row173_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_9b115_row37_col2, #T_9b115_row65_col5 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_9b115_row37_col5, #T_9b115_row54_col5, #T_9b115_row127_col5, #T_9b115_row209_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_9b115_row38_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_9b115_row38_col5, #T_9b115_row153_col2, #T_9b115_row180_col5, #T_9b115_row181_col5, #T_9b115_row183_col2, #T_9b115_row200_col2, #T_9b115_row215_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_9b115_row39_col2, #T_9b115_row116_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_9b115_row39_col5 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_9b115_row40_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9b115_row41_col2, #T_9b115_row153_col5, #T_9b115_row210_c

# %%
df_ai_dsharec.corr(method='spearman')
# Out:
#                                Pearson (All)  Pearson (Citable)  \
# Pearson (All)                       1.000000           0.858786
# Pearson (Citable)                   0.858786           1.000000
# Pearson Diff (Citable - All)       -0.288668           0.169425
# Spearman (All)                      0.646270           0.661973
# Spearman (Citable)                  0.549876           0.741255
# Spearman Diff (Citable - All)      -0.087983           0.173067
#
#                                Pearson Diff (Citable - All)  Spearman (All)  \
# Pearson (All)                                     -0.288668        0.646270
# Pearson (Citable)                                  0.169425        0.661973
# Pearson Diff (Citable - All)                       1.000000        0.029024
# Spearman (All)                                     0.029024        1.000000
# Spearman (Citable)                                 0.310104        0.799961
# Spearman Diff (Citable - All)                      0.504400       -0.203856
#
#                                Spearman (Citable)  \
# Pearson (All)                            0.549876
# Pearson (Citable)                        0.741255
# Pearson Diff (Citable - All)             0.310104
# Spearman (All)                           0.799961
# Spearman (Citable)                       1.000000
# Spearman Diff (Citable - All)            0.350533
#
#                                Spearman Diff (Citable - All)
# Pearson (All)                                      -0.087983
# Pearson (Citable)                                   0.173067
# Pearson Diff (Citable - All)                        0.504400
# Spearman (All)                                     -0.203856
# Spearman (Citable)                                  0.350533
# Spearman Diff (Citable - All)                       1.000000

# %% [markdown]
# ## 2. AI vs CShareD Correlation Comparison
#
# This section compares the correlations of **Activity Index (AI)** versus **CShareD**.

# %%
df_ai_cshared = get_comparison_table('AI vs CShareD')
display_styled_table(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'Table 2: AI vs CShareD (All vs. Citable)')
plot_comparison(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'AI vs CShareD')
# Out:
# <style type="text/css">
# #T_f23b3 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_
b3_row64_col5, #T_f23b3_row65_col5, #T_f23b3_row66_col2, #T_f23b3_row66_col5, #T_f23b3_row67_col2, #T_f23b3_row67_col5, #T_f23b3_row68_col2, #T_f23b3_row68_col5, #T_f23b3_row69_col2, #T_f23b3_row69_col5, #T_f23b3_row70_col2, #T_f23b3_row70_col5, #T_f23b3_row71_col2, #T_f23b3_row71_col5, #T_f23b3_row72_col5, #T_f23b3_row73_col5, #T_f23b3_row74_col2, #T_f23b3_row74_col5, #T_f23b3_row75_col2, #T_f23b3_row75_col5, #T_f23b3_row76_col2, #T_f23b3_row76_col5, #T_f23b3_row77_col2, #T_f23b3_row77_col5, #T_f23b3_row78_col5, #T_f23b3_row79_col5, #T_f23b3_row80_col2, #T_f23b3_row80_col5, #T_f23b3_row81_col5, #T_f23b3_row82_col5, #T_f23b3_row83_col2, #T_f23b3_row83_col5, #T_f23b3_row84_col2, #T_f23b3_row84_col5, #T_f23b3_row85_col2, #T_f23b3_row85_col5, #T_f23b3_row86_col2, #T_f23b3_row86_col5, #T_f23b3_row87_col5, #T_f23b3_row88_col2, #T_f23b3_row88_col5, #T_f23b3_row89_col5, #T_f23b3_row90_col2, #T_f23b3_row90_col5, #T_f23b3_row91_col2, #T_f23b3_row91_col5, #T_f23b3_row92_col2, #T_f23b3_row92_col5, #T_f23b3_row93_col2, #T_f23b3_row93_col5, #T_f23b3_row94_col2, #T_f23b3_row94_col5, #T_f23b3_row95_col2, #T_f23b3_row95_col5, #T_f23b3_row96_col2, #T_f23b3_row96_col5, #T_f23b3_row97_col2, #T_f23b3_row97_col5, #T_f23b3_row98_col2, #T_f23b3_row98_col5, #T_f23b3_row99_col5, #T_f23b3_row100_col5, #T_f23b3_row101_col2, #T_f23b3_row101_col5, #T_f23b3_row102_col2, #T_f23b3_row102_col5, #T_f23b3_row103_col5, #T_f23b3_row104_col2, #T_f23b3_row104_col5, #T_f23b3_row105_col5, #T_f23b3_row106_col2, #T_f23b3_row106_col5, #T_f23b3_row107_col2, #T_f23b3_row107_col5, #T_f23b3_row108_col2, #T_f23b3_row108_col5, #T_f23b3_row10 ...

# %% [markdown]
# ## 3. F-Measure vs DShareC (ShareC) Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **DShareC**.

# %%
df_f_dsharec = get_comparison_table('F-Measure vs DShareC')
display_styled_table(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'Table 3: F-Measure vs DShareC (All vs. Citable)')
plot_comparison(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'F-Measure vs DShareC (ShareC)')
# Out:
# <style type="text/css">
# #T_89693 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_89693 td {
#   text-align: right;
# }
# #T_89693 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_89693_row0_col2, #T_89693_row12_col5, #T_89693_row69_col5, #T_89693_row171_col2, #T_89693_row204_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T
col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_89693_row26_col2, #T_89693_row33_col2, #T_89693_row38_col5, #T_89693_row59_col2, #T_89693_row73_col2, #T_89693_row83_col2, #T_89693_row119_col5, #T_89693_row162_col5, #T_89693_row179_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_89693_row27_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_89693_row27_col5, #T_89693_row137_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_89693_row28_col2, #T_89693_row64_col2, #T_89693_row68_col5, #T_89693_row149_col2, #T_89693_row185_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_89693_row28_col5, #T_89693_row49_col2, #T_89693_row70_col2, #T_89693_row125_col2, #T_89693_row189_col2, #T_89693_row218_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_89693_row29_col2, #T_89693_row31_col2, #T_89693_row47_col5, #T_89693_row94_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_89693_row30_col2, #T_89693_row34_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_89693_row30_col5, #T_89693_row153_col5, #T_89693_row156_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_89693_row31_col5, #T_89693_row32_col5, #T_89693_row53_col2, #T_89693_row67_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_89693_row32_col2 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_89693_row33_col5, #T_89693_row38_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_89693_row34_col5, #T_89693_row46_col5, #T_89693_row63_col2, #T_89693_row81_col5, #T_89693_row143_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_89693_row35_col2, #T_89693_row212_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_89693_row35_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_89693_row36_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_89693_row36_col5, #T_89693_row62_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_89693_row37_col2, #T_89693_row127_col5, #T_89693_row130_col5, #T_89693_row186_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_89693_row39_col5, #T_89693_row125_col5, #T_89693_row131_col5, #T_89693_row168_col5, #T_89693_row206_col5 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_89693_row40_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_89693_row40_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_89693_row41_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_89693_row41_col5, #T_89693_row185_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_89693_row42_col2, #T_89693_row206_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_89693_row43_col2, #T_89693_row76_col5, #T_89693_row123_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_89693_row43_col5, #T_89693_row52_col5 {
#   background-color: #e6d7cf;
#   color: #00000

# %%
df_f_dsharec.corr(method='spearman')
# Out:
#                                Pearson (All)  Pearson (Citable)  \
# Pearson (All)                       1.000000           0.899972
# Pearson (Citable)                   0.899972           1.000000
# Pearson Diff (Citable - All)       -0.285866           0.108430
# Spearman (All)                      0.672047           0.667838
# Spearman (Citable)                  0.606586           0.710343
# Spearman Diff (Citable - All)      -0.126484           0.037505
#
#                                Pearson Diff (Citable - All)  Spearman (All)  \
# Pearson (All)                                     -0.285866        0.672047
# Pearson (Citable)                                  0.108430        0.667838
# Pearson Diff (Citable - All)                       1.000000       -0.042236
# Spearman (All)                                    -0.042236        1.000000
# Spearman (Citable)                                 0.190879        0.821756
# Spearman Diff (Citable - All)                      0.462620       -0.290207
#
#                                Spearman (Citable)  \
# Pearson (All)                            0.606586
# Pearson (Citable)                        0.710343
# Pearson Diff (Citable - All)             0.190879
# Spearman (All)                           0.821756
# Spearman (Citable)                       1.000000
# Spearman Diff (Citable - All)            0.231286
#
#                                Spearman Diff (Citable - All)
# Pearson (All)                                      -0.126484
# Pearson (Citable)                                   0.037505
# Pearson Diff (Citable - All)                        0.462620
# Spearman (All)                                     -0.290207
# Spearman (Citable)                                  0.231286
# Spearman Diff (Citable - All)                       1.000000

# %% [markdown]
# ## 4. F-Measure vs CShareD Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **CShareD**.

# %%
df_f_cshared = get_comparison_table('F-Measure vs CShareD')
display_styled_table(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'Table 4: F-Measure vs CShareD (All vs. Citable)')
plot_comparison(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'F-Measure vs CShareD')
# Out:
# <style type="text/css">
# #T_d8aa2 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d8aa2 td {
#   text-align: right;
# }
# #T_d8aa2 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_d8aa2_row0_col2, #T_d8aa2_row1_col2, #T_d8aa2_row1_col5, #T_d8aa2_row2_col2, #T_d8aa2_row3_col2, #T_d8aa2_row4_col2, #T_d8aa2_row5_col2, #T_d8aa2_row5_col5, #T_d8aa2_row8_col2, #T_d8aa2_row9_col2, #T_d8aa2_row10_col2, #T_d8aa2_row11_col2, #T_d8aa2_row12_col2, #T_d8aa2_row12_col5, #T_d8aa2_row13_col2, #T_d8aa2_row14_col2, #T_d8aa2_row15_col2, #T_d8aa2_row16_col2, #T_d8aa2_row17_col2, #T_d8aa2_row17_col5, #T_d8aa2_row18_col2, #T_d8aa2_row18_col5, #T_d8aa2_row19_col2, #T_d8aa2_row20_col2, #T_d8aa2_row21_col2, #T_d8aa2_row21_col5, #T_d8aa2_row22_col2, #T_d8aa2_row23_col2, #T_d8aa2_row25_col2, #T_d8aa2_row26_col2, #T_d8aa2_row26_col5, #T_d8aa2_row28_col2, #T_d8aa2_row29_col2, #T_d8aa2_row30_col2, #T_d8aa2_row31_col2, #T_d8aa2_row32_col2, #T_d8aa2_row33_col2, #T_d8aa2_row34_col2, #T_d8aa2_row35_col2, #T_d8aa2_row36_col2, #T_d8aa2_row37_col2, #T_d8aa2_row39_col2, #T_d8aa2_row40_col2, #T_d8aa2_row41_col2, #T_d8aa2_row42_col2, #T_d8aa2_row42_col5, #T_d8aa2_row44_col2, #T_d8aa2_row45_col2, #T_d8aa2_row47_col2, #T_d8aa2_row48_col2, #T_d8aa2_row50_col2, #T_d8aa2_row51_col2, #T_d8aa2_row53_col2, #T_d8aa2_row54_col2, #T_d8aa2_row55_col2, #T_d8aa2_row56_col2, #T_d8aa2_row57_col2, #T_d8aa2_row58_col2, #T_d8aa2_row59_col2, #T_d8aa2_row61_col2, #T_d8aa2_row62_col2, #T_d8aa2_row62_col5, #T_d8aa2_row63_col2, #T_d8aa2_row64_col2, #T_d8aa2_row65_col2, #T_d8aa2_row65_col5, #T_d8aa2_row66_col2, #T_d8aa2_row67_col2, #T_d8aa2_row68_col2, #T_d8aa2_row70_col2, #T_d8aa2_row71_col2, #T_d8aa2_row73_col2, #T_d8aa2_row74_col2, #T_d8aa2_row75_col2, #T_d8aa2_row76_col2, #T_d8aa2_row77_col2, #T_d8aa2_row78_col2, #T_d8aa2_row79_col2, #T_d8aa2_row80_col2, #T_d8aa2_row81_col2, #T_d8aa2_row83_col2, #T_d8aa2_row84_col2, #T_d8aa2_row85_col2, #T_d8aa2_row85_col5, #T_d8aa2_row86_col2, #T_d8aa2_row88_col2, #T_d8aa2_row89_col2, #T_d8aa2_row89_col5, #T_d8aa2_row91_col2, #T_d8aa2_row92_col2, #T_d8aa2_row92_col5, #T_d8aa2_row93_col2, #T_d8aa2_row94_col2, #T_d8aa2_row95_col2, #T_d8aa2_row96_col2, #T_d8aa2_row99_col5, #T_d8aa2_row101_col2, #T_d8aa2_row101_col5, #T_d8aa2_row103_col2, #T_d8aa2_row103_col5, #T_d8aa2_row104_col2, #T_d8aa2_row104_col5, #T_d8aa2_row105_col2, #T_d8aa2_row106_col2, #T_d8aa2_row107_col2, #T_d8aa2_row109_col2, #T_d8aa2_row110_col2, #T_d8aa2_row111_col2, #T_d8aa2_row111_col5, #T_d8aa2_row112_col2, #T_d8aa2_row112_col5, #T_d8aa2_row113_col2, #T_d8aa2_row114_col2, #T_d8aa2_row114_col5, #T_d8aa2_row115_col2, #T_d8aa2_row116_col2, #T_d8aa2_row117_col2, #T_d8aa2_row119_col2, #T_d8aa2_row119_col5, #T_d8aa2_row122_col2, #T_d8aa2_row123_col2, #T_d8aa2_row124_col2, #T_d8aa2_row125_col5, #T_d8aa2_row129_col2, #T_d8aa2_row135_col2, #T_d8aa2_row141_col2, #T_d8aa2_row146_col2, #T_d8aa2_row148_col2, #T_d8aa2_row149_col2, #T_d8aa2_row203_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_d8aa2_row0_col5, #T_d8aa2_row2_col5, #T_d8aa2_row3_col5, #T_d8aa2_row4_col5, #T_d8aa2_row6_col2, #T_d8aa2_row6_col5, #T_d8aa2_row8_col5, #T_d8aa2_row9_col5, #T_d8aa2_row10_col5, #T_d8aa2_row11_col5, #T_d8aa2_row13_col5, #T_d8aa2_row14_col5, #T_d8aa2_row15_col5, #T_d8aa2_row16_col5, #T_d8aa2_row19_col5, #T_d8aa2_row20_col5, #T_d8aa2_row22_col5, #T_d8aa2_row23_col5, #T_d8aa2_row24_col2, #T_d8aa2_row24_col5, #T_d8aa2_row25_col5, #T_d8aa2_row27_col2, #T_d8aa2_row27_col5, #T_d8aa2_row28_col5, #T_d8aa2_row29_col5, #T_d8aa2_row30_col5, #T_d8aa2_row31_col5, #T_d8aa2_row32_col5, #T_d8aa2_row33_col5, #T_d8aa2_row34_col5, #T_d8aa2_row35_col5, #T_d8aa2_row36_col5, #T_d8aa2_row37_col5, #T_d8aa2_row38_col2, #T_d8aa2_row38_col5, #T_d8aa2_row39_col5, #T_d8aa2_row40_col5, #T_d8aa2_row44_col5, #T_d8aa2_row45_col5, #T_d8aa2_row46_col2, #T_d8aa2_row46_col5, #T_d8aa2_row47_col5, #T_d8aa2_row49_col2, #T_d8aa2_row49_col5, #T_d8aa2_row50_col5, #T_d8aa2_row51_col5, #T_d8aa2_row52_col2, #T_d8aa2_row52_col5, #T_d8aa2_row53_col5, #T_d8aa2_row54_col5, #T_d8aa2_row55_col5, #T_d8aa2_row56_col5, #T_d8aa2_row57_col5, #T_d8aa2_row58_col5, #T_d8aa2_row59_col5, #T_d8aa2_row60_col2, #T_d8aa2_row60_col5, #T_d8aa2_row61_col5, #T_d8aa2_row63_col5, #T_d8aa2_row64_col5, #T_d8aa2_row66_col5, #T_d8aa2_row67_col5, #T_d8aa2_row69_col2, #T_d8aa2_row69_col5, #T_d8aa2_row70_col5, #T_d8aa2_row71_col5, #T_d8aa2_row72_col2, #T_d8aa2_row72_col5, #T_d8aa2_row73_col5, #T_d8aa2_row74_col5, #T_d8aa2_row75_col5, #T_d8aa2_row76_col5, #T_d8aa2_row77_col5, #T_d8aa2_row78_col5, #T_d8aa2_row79_col5, #T_d8aa2_row80_col5, #T_d8aa2_row81_col5, #T_d8aa2_row83_col5, #T_d8aa2_row84_col5, #T_d8aa2_row86_col5, #T_d8aa2_row88_col5, #T_d8aa2_row91_col5, #T_d8aa2_row93_col5, #T_d8aa2_row96_col5, #T_d8aa2_row105_col5, #T_d8aa2_row106_col5, #T_d8aa2_row109_col5, #T_d8aa2_row115_col5, #T_d8aa2_row120_col2, #T_d8aa2_row123_col5, #T_d8aa2_row126_col5, #T_d8aa2_row136_col2, #T_d8aa2_row144_col5, #T_d8aa2_row194_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_d8aa2_row7_col2, #T_d8aa2_row7_col5, #T_d8aa2_row41_col5, #T_d8aa2_row43_col5, #T_d8aa2_row82_col2, #T_d8aa2_row87_col2, #T_d8aa2_row95_col5, #T_d8aa2_row113_col5, #T_d8aa2_row118_col2, #T_d8aa2_row121_col5, #T_d8aa2_row126_col2, #T_d8aa2_row127_col5, #T_d8aa2_row131_col2, #T_d8aa2_row143_col2, #T_d8aa2_row209_col2, #T_d8aa2_row219_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_d8aa2_row43_col2, #T_d8aa2_row68_col5, #T_d8aa2_row87_col5, #T_d8aa2_row90_col2, #T_d8aa2_row94_col5, #T_d8aa2_row100_col2, #T_d8aa2_row102_col2, #T_d8aa2_row108_col5, #T_d8aa2_row121_col2, #T_d8aa2_row129_col5, #T_d8aa2_row132_col2, #T_d8aa2_row133_col2, #T_d8aa2_row142_col2, #T_d8aa2_row144_col2, #T_d8aa2_row147_col2, #T_d8aa2_row167_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_d8aa2_row48_col5, #T_d8aa2_row82_col5, #T_d8aa2_row97_col5, #T_d8aa2_row99_col2, #T_d8aa2_row125_col2, #T_d8aa2_row130_col2, #T_d8aa2_row130_col5, #T_d8aa2_row139_col5, #T_d8aa2_row214_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_d8aa2_row90_col5, #T_d8aa2_row134_col2, #T_d8aa2_row152_col2, #T_d8aa2_row165_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_d8aa2_row97_col2, #T_d8aa2_row98_col5, #T_d8aa2_row120_col5, #T_d8aa2_row132_col5, #T_d8aa2_row138_col2, #T_d8aa2_row153_col2, #T_d8aa2_row157_col2, #T_d8aa2_row163_col2, #T_d8aa2_row164_col2, #T_d8aa2_row173_col2, #T_d8aa2_row184_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_d8aa2_row98_col2, #T_d8aa2_row128_col5, #T_d8aa2_row181_col2, #T_d8aa2_row199_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d8aa2_row100_col5, #T_d8aa2_row116_col5, #T_d8aa2_row127_col2, #T_d8aa2_row139_col2, #T_d8aa2_row140_col2, #T_d8aa2_row143_col5, #T_d8aa2_row145_col5, #T_d8aa2_row188_col2, #T_d8aa2_row189_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_d8aa2_row102_col5, #T_d8aa2_row122_col5, #T_d8aa2_row128_col2, #T_d8aa2_row138_col5, #T_d8aa2_row156_col2, #T_d8aa2_row160_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_d8aa2_row107_col5, #T_d8aa2_row110_col5, #T_d8aa2_row124_col5, #T_d8aa2_row142_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_d8aa2_row108_col2, #T_d8aa2_row186_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_d8aa2_row117_col5, #T_d8aa2_row146_col5, #T_d8aa2_row149_col5, #T_d8aa2_row151_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_d8aa2_row118_col5, #T_d8aa2_row131_col5, #T_d8aa2_row150_col2, #T_d8aa2_row160_col5, #T_d8aa2_row185_col5, #T_d8aa2_row202_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_d8aa2_row133_col5, #T_d8aa2_row159_col2, #T_d8aa2_row183_col2, #T_d8aa2_row187_col5, #T_d8aa2_row210_col5, #T_d8aa2_row223_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_d8aa2_row134_col5, #T_d8aa2_row180_col2, #T_d8aa2_row217_col2, #T_d8aa2_row219_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d8aa2_row135_col5, #T_d8aa2_row136_col

# %%
df_f_cshared.corr(method='spearman')
# Out:
#                                Pearson (All)  Pearson (Citable)  \
# Pearson (All)                       1.000000           0.991810
# Pearson (Citable)                   0.991810           1.000000
# Pearson Diff (Citable - All)        0.681331           0.725714
# Spearman (All)                      0.943185           0.937473
# Spearman (Citable)                  0.951728           0.955293
# Spearman Diff (Citable - All)       0.548357           0.566565
#
#                                Pearson Diff (Citable - All)  Spearman (All)  \
# Pearson (All)                                      0.681331        0.943185
# Pearson (Citable)                                  0.725714        0.937473
# Pearson Diff (Citable - All)                       1.000000        0.640981
# Spearman (All)                                     0.640981        1.000000
# Spearman (Citable)                                 0.670517        0.949572
# Spearman Diff (Citable - All)                      0.479679        0.468584
#
#                                Spearman (Citable)  \
# Pearson (All)                            0.951728
# Pearson (Citable)                        0.955293
# Pearson Diff (Citable - All)             0.670517
# Spearman (All)                           0.949572
# Spearman (Citable)                       1.000000
# Spearman Diff (Citable - All)            0.619949
#
#                                Spearman Diff (Citable - All)
# Pearson (All)                                       0.548357
# Pearson (Citable)                                   0.566565
# Pearson Diff (Citable - All)                        0.479679
# Spearman (All)                                      0.468584
# Spearman (Citable)                                  0.619949
# Spearman Diff (Citable - All)                       1.000000

# %% [markdown]
# ## 5. Summary Statistics and Overall Analysis (Absolute Discrepancies)
#
# To synthesize the comparison, let's look at the summary statistics of the **absolute differences** across all 26 OpenAlex Fields for each of the four indicator pairs.
#
# Using absolute values is essential because it measures the magnitude of the discrepancy (change) regardless of whether the correlation went up or down. For example, a large negative change like -0.76708 represents a major discrepancy of 0.76708 in absolute terms. Computing statistics on signed differences can cause positive and negative changes to cancel each other out, hiding the true extent of the changes.

# %%
summary_data = []
pairs_mapping = {
    'AI vs DShareC': 'AI vs DShareC',
    'AI vs CShareD': 'AI vs CShareD',
    'F-Measure vs DShareC': 'F-Measure vs DShareC',
    'F-Measure vs CShareD': 'F-Measure vs CShareD'
}

for user_name, csv_name in pairs_mapping.items():
    df_p = get_comparison_table(csv_name)
    pearson_abs = df_p['Pearson Diff (Citable - All)'].abs()
    spearman_abs = df_p['Spearman Diff (Citable - All)'].abs()
    summary_data.append({
        'Indicator Pair': user_name,
        'Mean Abs Pearson Diff': pearson_abs.mean(),
        'Median Abs Pearson Diff': pearson_abs.median(),
        'Max Abs Pearson Diff': pearson_abs.max(),
        'Min Abs Pearson Diff': pearson_abs.min(),
        'Mean Abs Spearman Diff': spearman_abs.mean(),
        'Median Abs Spearman Diff': spearman_abs.median(),
        'Max Abs Spearman Diff': spearman_abs.max(),
        'Min Abs Spearman Diff': spearman_abs.min()
    })

df_summary = pd.DataFrame(summary_data).set_index('Indicator Pair')

styled_summary = df_summary.style.format("{:.5f}")\
    .background_gradient(cmap="Reds", vmin=0.0, vmax=0.3)\
    .set_caption("<b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|Citable - All|)</b>")\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#2c3e50'), ('color', 'white'), ('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('text-align', 'right')]},
        {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
    ])
display(styled_summary)
global text
text = text + "<h2>Overall Comparison Summary</h2>" + styled_summary.to_html() + "<br><br>"
# Out:
# <style type="text/css">
# #T_81683 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_81683 td {
#   text-align: right;
# }
# #T_81683 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_81683_row0_col0 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_81683_row0_col1, #T_81683_row0_col5 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_81683_row0_col2, #T_81683_row0_col6, #T_81683_row2_col2, #T_81683_row2_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_81683_row0_col3 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_81683_row0_col4 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_81683_row0_col7, #T_81683_row1_col0, #T_81683_row1_col1, #T_81683_row1_col2, #T_81683_row1_col3, #T_81683_row1_col4, #T_81683_row1_col5, #T_81683_row1_col6, #T_81683_row1_col7, #T_81683_row2_col3, #T_81683_row2_col7, #T_81683_row3_col1, #T_81683_row3_col3, #T_81683_row3_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_81683_row2_col0 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_81683_row2_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_81683_row2_col4 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_81683_row2_col5 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_81683_row3_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_81683_row3_col2 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_81683_row3_col4 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_81683_row3_col5 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_81683_row3_col6 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81683" class="dataframe">
#   <caption><b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|Citable - All|)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81683_level0_col0" class="col_heading level0 col0" >Mean Abs Pearson Diff</th>
#       <th id="T_81683_level0_col1" class="col_heading level0 col1" >Median Abs Pearson Diff</th>
#       <th id="T_81683_level0_col2" class="col_heading level0 col2" >Max Abs Pearson Diff</th>
#       <th id="T_81683_level0_col3" class="col_heading level0 col3" >Min Abs Pearson Diff</th>
#       <th id="T_81683_level0_col4" class="col_heading level0 col4" >Mean Abs Spearman Diff</th>
#       <th id="T_81683_level0_col5" class="col_heading level0 col5" >Median Abs Spearman Diff</th>
#       <th id="T_81683_level0_col6" class="col_heading level0 col6" >Max Abs Spearman Diff</th>
#       <th id="T_81683_level0_col7" class="col_heading level0 col7" >Min Abs Spearman Diff</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator Pair</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81683_level0_row0" class="row_heading level0 row0" >AI vs DShareC</th>
#       <td id="T_81683_row0_col0" class="data row0 col0" >0.08607</td>
#       <td id="T_81683_row0_col1" class="data row0 col1" >0.07184</td>
#       <td id="T_81683_row0_col2" class="data row0 col2" >0.56241</td>
#       <td id="T_81683_row0_col3" class="data row0 col3" >0.00163</td>
#       <td id="T_81683_row0_col4" class="data row0 col4" >0.10748</td>
#       <td id="T_81683_row0_col5" class="data row0 col5" >0.07224</td>
#       <td id="T_81683_row0_col6" class="data row0 col6" >0.71949</td>
#       <td id="T_81683_row0_col7" class="data row0 col7" >0.00026</td>
#     </tr>
#     <tr>
#       <th id="T_81683_level0_row1" class="row_heading level0 row1" >AI vs CShareD</th>
#       <td id="T_81683_row1_col0" class="data row1 col0" >0.00000</td>
#       <td id="T_81683_row1_col1" class="data row1 col1" >0.00000</td>
#       <td id="T_81683_row1_col2" class="data row1 col2" >0.00000</td>
#       <td id="T_81683_row1_col3" class="data row1 col3" >0.00000</td>
#       <td id="T_81683_row1_col4" class="data row1 col4" >0.00000</td>
#       <td id="T_81683_row1_col5" class="data row1 col5" >0.00000</td>
#       <td id="T_81683_row1_col6" class="data row1 col6" >0.00000</td>
#       <td id="T_81683_row1_col7" class="data row1 col7" >0.00000</td>
#     </tr>
#     <tr>
#       <th id="T_81683_level0_row2" class="row_heading level0 row2" >F-Measure vs DShareC</th>
#       <td id="T_81683_row2_col0" class="data row2 col0" >0.07679</td>
#       <td id="T_81683_row2_col1" class="data row2 col1" >0.05250</td>
#       <td id="T_81683_row2_col2" class="data row2 col2" >0.56242</td>
#       <td id="T_81683_row2_col3" class="data row2 col3" >0.00006</td>
#       <td id="T_81683_row2_col4" class="data row2 col4" >0.09894</td>
#       <td id="T_81683_row2_col5" class="data row2 col5" >0.06194</td>
#       <td id="T_81683_row2_col6" class="data row2 col6" >0.71949</td>
#       <td id="T_81683_row2_col7" class="data row2 col7" >0.00068</td>
#     </tr>
#     <tr>
#       <th id="T_81683_level0_row3" class="row_heading level0 row3" >F-Measure vs CShareD</th>
#       <td id="T_81683_row3_col0" class="data row3 col0" >0.01613</td>
#       <td id="T_81683_row3_col1" class="data row3 col1" >0.00097</td>
#       <td id="T_81683_row3_col2" class="data row3 col2" >0.23705</td>
#       <td id="T_81683_row3_col3" class="data row3 col3" >0.00000</td>
#       <td id="T_81683_row3_col4" class="data row3 col4" >0.02178</td>
#       <td id="T_81683_row3_col5" class="data row3 col5" >0.00252</td>
#       <td id="T_81683_row3_col6" class="data row3 col6" >0.18872</td>
#       <td id="T_81683_row3_col7" class="data row3 col7" >0.00000</td>
#     </tr>
#   </tbody>
# </table>

# %%
global text
text = text + "</body></html>"
with open("All_vs_Citable Documents.html", "w", encoding="utf-8") as f:
    f.write(text)
print("Saved report to All_vs_Citable.html")
# Out:
# Saved report to All_vs_Citable.html
