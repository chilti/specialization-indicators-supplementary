# %% [markdown]
# # Comparison of Global Context Correlations: All Documents vs. Citable Documents
#
# This notebook performs a systematic comparison between the correlations calculated for **All Documents** and **Citable Documents** in the Global Context across different  OpenAlex Topics.

# %%
#Montar mi google drive para poder usar los archivos
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext/"
# !ls
# Out:
# /content/gdrive/.shortcut-targets-by-id/0B5aSrRJgnViLfm9LWl9TY21TWm5wSU0zbkgzc2YyeEp3RzJMaEJOR2FWbFkxVEZYTjNQd1E/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext
# 'All_vs_Citable Documents.html'
#  figuras
#  ManuscriptActivityIndexFmeasure_ESI_GlobalContext.ipynb
#  manuscriptFiguresAndTables.html
#  pearson_correlation_AI_FMeasure.csv
#  scatterplots
#  scatterplots.html
#  spearman_correlation_2024.csv
#  Spearman_correlation_AI_FMeasure.csv

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set plotting style
sns.set_theme(style="whitegrid")
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['DejaVu Sans', 'Arial', 'Helvetica'],
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titlesize': 14,
    'figure.titleweight': 'bold'
})


# Initialize HTML report container
text = """
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>Comparison Analysis Report</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; color: #2c3e50; }
        h1, h2, h3 { color: #2c3e50; }
        table { border-collapse: collapse; width: 100%; margin-bottom: 20px; }
        th, td { border: 1px solid #bdc3c7; padding: 8px; text-align: left; }
        th { background-color: #f4f6f7; font-weight: bold; }
        img { max-width: 100%; height: auto; display: block; margin: 20px 0; }
    </style>
</head>
<body>
<h1>Comparison Analysis Report (All vs. Citable Documents)</h1>
"""

# %%
# Define paths to the CSV files
paths = {
    'all_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/All_Documents/OpenAlex/GlobalContext/pearson_correlation_AI_FMeasure.csv',
    'all_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/All_Documents/OpenAlex/GlobalContext/Spearman_correlation_AI_FMeasure.csv',
    'citable_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext/pearson_correlation_AI_FMeasure.csv',
    'citable_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext/Spearman_correlation_AI_FMeasure.csv'
}

# Load files
dfs = {}
for name, path in paths.items():
    if not os.path.exists(path):
        # Try relative paths as fallback
        if '2026' in path:
            rel_path = f'Global Context/{os.path.basename(path)}'
        else:
            rel_path = f'../../ManuscriptExperiments/Global Context/{os.path.basename(path)}'
        if os.path.exists(rel_path):
            path = rel_path

    dfs[name] = pd.read_csv(path, index_col=0)
    print(f"Successfully loaded {name} (Shape: {dfs[name].shape})")
# Out:
# Successfully loaded all_pearson (Shape: (26, 11))
# Successfully loaded all_spearman (Shape: (26, 11))
# Successfully loaded citable_pearson (Shape: (26, 11))
# Successfully loaded citable_spearman (Shape: (26, 11))

# %%
def get_comparison_table(col_name):
    """
    Creates a side-by-side comparison table for a specific correlation column.
    """
    # Base index of OpenAlex Fields from the Pearson All dataset
    index_ref = dfs['all_pearson'].index

    df_comp = pd.DataFrame(index=index_ref)

    # Pearson
    df_comp['Pearson (All)'] = dfs['all_pearson'][col_name]
    df_comp['Pearson (Citable)'] = dfs['citable_pearson'][col_name]
    df_comp['Pearson Diff (Citable - All)'] = df_comp['Pearson (Citable)'] - df_comp['Pearson (All)']

    # Spearman (aligning indices)
    df_comp['Spearman (All)'] = df_comp.index.map(dfs['all_spearman'][col_name])
    df_comp['Spearman (Citable)'] = df_comp.index.map(dfs['citable_spearman'][col_name])
    df_comp['Spearman Diff (Citable - All)'] = df_comp['Spearman (Citable)'] - df_comp['Spearman (All)']

    # Sort OpenAlex Fields alphabetically
    df_comp = df_comp.sort_index()
    return df_comp

def display_styled_table(df, title):
    """
    Applies advanced pandas styler to color-code difference columns and display.
    """
    styled = df.style.format("{:.4f}")\
        .background_gradient(cmap="coolwarm", subset=["Pearson Diff (Citable - All)", "Spearman Diff (Citable - All)"], vmin=-0.2, vmax=0.2)\
        .set_caption(f"<b style='font-size: 14px;'>{title}</b>")\
        .set_table_styles([
            {'selector': 'th', 'props': [('background-color', '#f4f6f7'), ('color', '#2c3e50'), ('font-weight', 'bold'), ('text-align', 'center')]},
            {'selector': 'td', 'props': [('text-align', 'right')]},
            {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
        ])
    display(styled)
    global text
    text = text + f"<h2>{title}</h2>" + styled.to_html() + "<br><br>"

def plot_comparison(df, user_name):
    """
    Generates side-by-side horizontal bar plots to visualize the differences in correlations.
    """
    # Prepare Pearson data for Seaborn
    df_pearson = pd.DataFrame({
        'OpenAlex Field': df.index,
        'All Documents': df['Pearson (All)'].values,
        'Citable Documents': df['Pearson (Citable)'].values
    }).melt(id_vars='OpenAlex Field', var_name='Dataset', value_name='Pearson Correlation')

    # Prepare Spearman data for Seaborn
    df_spearman = pd.DataFrame({
        'OpenAlex Field': df.index,
        'All Documents': df['Spearman (All)'].values,
        'Citable Documents': df['Spearman (Citable)'].values
    }).melt(id_vars='OpenAlex Field', var_name='Dataset', value_name='Spearman Correlation')

    fig, axes = plt.subplots(1, 2, figsize=(16, 9), sharey=True)

    # Harmonious colors: Cool Blue for All, Warm Coral for Citable
    colors = {'All Documents': '#2b7bba', 'Citable Documents': '#e76f51'}

    # Pearson Subplot
    sns.barplot(
        data=df_pearson,
        y='OpenAlex Field',
        x='Pearson Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[0]
    )
    axes[0].set_title("Pearson Correlation Coefficient", fontsize=13, pad=10)
    axes[0].set_xlabel("Correlation Value")
    axes[0].set_ylabel("OpenAlex Field")
    axes[0].set_xlim(-1.05, 1.05)
    axes[0].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[0].legend().set_visible(False)

    # Spearman Subplot
    sns.barplot(
        data=df_spearman,
        y='OpenAlex Field',
        x='Spearman Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[1]
    )
    axes[1].set_title("Spearman Correlation Coefficient", fontsize=13, pad=10)
    axes[1].set_xlabel("Correlation Value")
    axes[1].set_ylabel("")
    axes[1].set_xlim(-1.05, 1.05)
    axes[1].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[1].legend().set_visible(False)

    # Add single common legend
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.97), ncol=2, fontsize=11)

    plt.suptitle(f"Correlation Comparison: {user_name} (All vs. Citable)", fontsize=15, y=1.03)
    plt.tight_layout()
    import os
    os.makedirs('figuras', exist_ok=True)
    fig_name_clean = user_name.replace(' ', '_').replace('/', '_').replace(':', '_').replace('(', '').replace(')', '')
    fig_filename = f"figuras/comparison_{fig_name_clean}.png"
    plt.savefig(fig_filename, bbox_inches='tight')
    global text
    text = text + f"<img src='{fig_filename}' alt='{user_name} Comparison'><br><br>\n"
    plt.show()

# %% [markdown]
# ## 1. AI vs DShareC Correlation Comparison
#
# This section compares the Pearson and Spearman correlations of **Activity Index (AI)** versus **DShareC**.
# This indicator measures how the proportion of publications (AI) relates to the document share in the citation distribution.

# %%
df_ai_dsharec = get_comparison_table('AI vs DShareC')
display_styled_table(df_ai_dsharec, 'Table 1: AI vs DShareC (All vs. Citable)')
plot_comparison(df_ai_dsharec, 'AI vs DShareC')
# Out:
# <style type="text/css">
# #T_24cca th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_24cca td {
#   text-align: right;
# }
# #T_24cca caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_24cca_row0_col2, #T_24cca_row0_col5, #T_24cca_row1_col5, #T_24cca_row2_col5, #T_24cca_row3_col2, #T_24cca_row3_col5, #T_24cca_row4_col5, #T_24cca_row5_col5, #T_24cca_row6_col5, #T_24cca_row7_col2, #T_24cca_row7_col5, #T_24cca_row8_col2, #T_24cca_row8_col5, #T_24cca_row9_col5, #T_24cca_row10_col2, #T_24cca_row10_col5, #T_24cca_row11_col2, #T_24cca_row11_col5, #T_24cca_row12_col5, #T_24cca_row13_col2, #T_24cca_row13_col5, #T_24cca_row14_col5, #T_24cca_row15_col2, #T_24cca_row15_col5, #T_24cca_row16_col5, #T_24cca_row17_col5, #T_24cca_row18_col5, #T_24cca_row19_col5, #T_24cca_row20_col5, #T_24cca_row21_col2, #T_24cca_row21_col5, #T_24cca_row22_col5, #T_24cca_row23_col2, #T_24cca_row23_col5, #T_24cca_row24_col2, #T_24cca_row24_col5, #T_24cca_row25_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_24cca_row1_col2, #T_24cca_row2_col2, #T_24cca_row4_col2, #T_24cca_row5_col2, #T_24cca_row6_col2, #T_24cca_row9_col2, #T_24cca_row12_col2, #T_24cca_row14_col2, #T_24cca_row16_col2, #T_24cca_row17_col2, #T_24cca_row18_col2, #T_24cca_row19_col2, #T_24cca_row20_col2, #T_24cca_row22_col2, #T_24cca_row25_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_24cca" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 1: AI vs DShareC (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24cca_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_24cca_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_24cca_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_24cca_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_24cca_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_24cca_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24cca_level0_row0" class="row_heading level0 row0" >Agricultural and Biological Sciences</th>
#       <td id="T_24cca_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_24cca_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_24cca_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_24cca_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_24cca_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_24cca_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row1" class="row_heading level0 row1" >Arts and Humanities</th>
#       <td id="T_24cca_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_24cca_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_24cca_row1_col2" class="data row1 col2" >-0.0000</td>
#       <td id="T_24cca_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_24cca_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_24cca_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row2" class="row_heading level0 row2" >Biochemistry, Genetics and Molecular Biology</th>
#       <td id="T_24cca_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_24cca_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_24cca_row2_col2" class="data row2 col2" >-0.0000</td>
#       <td id="T_24cca_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_24cca_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_24cca_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row3" class="row_heading level0 row3" >Business, Management and Accounting</th>
#       <td id="T_24cca_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_24cca_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_24cca_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_24cca_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_24cca_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_24cca_row3_col5" class="data row3 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row4" class="row_heading level0 row4" >Chemical Engineering</th>
#       <td id="T_24cca_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_24cca_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_24cca_row4_col2" class="data row4 col2" >-0.0000</td>
#       <td id="T_24cca_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_24cca_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_24cca_row4_col5" class="data row4 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row5" class="row_heading level0 row5" >Chemistry</th>
#       <td id="T_24cca_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_24cca_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_24cca_row5_col2" class="data row5 col2" >-0.0000</td>
#       <td id="T_24cca_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_24cca_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_24cca_row5_col5" class="data row5 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row6" class="row_heading level0 row6" >Computer Science</th>
#       <td id="T_24cca_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_24cca_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_24cca_row6_col2" class="data row6 col2" >-0.0000</td>
#       <td id="T_24cca_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_24cca_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_24cca_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row7" class="row_heading level0 row7" >Decision Sciences</th>
#       <td id="T_24cca_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_24cca_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_24cca_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_24cca_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_24cca_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_24cca_row7_col5" class="data row7 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row8" class="row_heading level0 row8" >Dentistry</th>
#       <td id="T_24cca_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_24cca_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_24cca_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_24cca_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_24cca_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_24cca_row8_col5" class="data row8 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row9" class="row_heading level0 row9" >Earth and Planetary Sciences</th>
#       <td id="T_24cca_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_24cca_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_24cca_row9_col2" class="data row9 col2" >-0.0000</td>
#       <td id="T_24cca_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_24cca_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_24cca_row9_col5" class="data row9 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_24cca_level0_row10" class="row_heading level0 row10" >Economics, Econometrics and Finance</th>
#       <td id="T_24cca_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_24cca_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_24cca_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_24cca_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_24cca_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_

# %% [markdown]
# ## 2. AI vs CShareD Correlation Comparison
#
# This section compares the correlations of **Activity Index (AI)** versus **CShareD**.

# %%
df_ai_cshared = get_comparison_table('AI vs CShareD')
display_styled_table(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'Table 2: AI vs CShareD (All vs. Citable)')
plot_comparison(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'AI vs CShareD')
# Out:
# <style type="text/css">
# #T_3f293 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_3f293 td {
#   text-align: right;
# }
# #T_3f293 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_3f293_row0_col2, #T_3f293_row8_col5, #T_3f293_row11_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_3f293_row0_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_3f293_row1_col2, #T_3f293_row17_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_3f293_row1_col5, #T_3f293_row25_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_3f293_row2_col2, #T_3f293_row7_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_3f293_row2_col5, #T_3f293_row8_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_3f293_row3_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_3f293_row3_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_3f293_row4_col2, #T_3f293_row13_col2, #T_3f293_row15_col5, #T_3f293_row16_col2, #T_3f293_row21_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_3f293_row4_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_3f293_row5_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_3f293_row5_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_3f293_row6_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_3f293_row6_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_3f293_row7_col5 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_3f293_row9_col2, #T_3f293_row18_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_3f293_row9_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_3f293_row10_col2, #T_3f293_row23_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_3f293_row10_col5, #T_3f293_row23_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_3f293_row11_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_3f293_row12_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_3f293_row12_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_3f293_row13_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_3f293_row14_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_3f293_row14_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_3f293_row15_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_3f293_row16_col5 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_3f293_row17_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_3f293_row18_col5 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_3f293_row19_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_3f293_row19_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_3f293_row20_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_3f293_row20_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_3f293_row21_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_3f293_row22_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_3f293_row22_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_3f293_row24_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_3f293_row24_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_3f293_row25_col5 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# </style>
# <table id="T_3f293" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 2: AI vs CShareD (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f293_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_3f293_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_3f293_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_3f293_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_3f293_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_3f293_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f293_level0_row0" class="row_heading level0 row0" >Engineering</th>
#       <td id="T_3f293_row0_col0" class="data row0 col0" >0.2360</td>
#       <td id="T_3f293_row0_col1" class="data row0 col1" >0.2921</td>
#       <td id="T_3f293_row0_col2" class="data row0 col2" >0.0561</td>
#       <td id="T_3f293_row0_col3" class="data row0 col3" >0.7155</td>
#       <td id="T_3f293_row0_col4" class="data row0 col4" >0.7270</td>
#       <td id="T_3f293_row0_col5" class="data row0 col5" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row1" class="row_heading level0 row1" >Physics and Astronomy</th>
#       <td id="T_3f293_row1_col0" class="data row1 col0" >0.1459</td>
#       <td id="T_3f293_row1_col1" class="data row1 col1" >0.1234</td>
#       <td id="T_3f293_row1_col2" class="data row1 col2" >-0.0225</td>
#       <td id="T_3f293_row1_col3" class="data row1 col3" >0.6494</td>
#       <td id="T_3f293_row1_col4" class="data row1 col4" >0.6636</td>
#       <td id="T_3f293_row1_col5" class="data row1 col5" >0.0142</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row2" class="row_heading level0 row2" >Materials Science</th>
#       <td id="T_3f293_row2_col0" class="data row2 col0" >0.1957</td>
#       <td id="T_3f293_row2_col1" class="data row2 col1" >0.2550</td>
#       <td id="T_3f293_row2_col2" class="data row2 col2" >0.0593</td>
#       <td id="T_3f293_row2_col3" class="data row2 col3" >0.5941</td>
#       <td id="T_3f293_row2_col4" class="data row2 col4" >0.6240</td>
#       <td id="T_3f293_row2_col5" class="data row2 col5" >0.0298</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row3" class="row_heading level0 row3" >Neuroscience</th>
#       <td id="T_3f293_row3_col0" class="data row3 col0" >0.2805</td>
#       <td id="T_3f293_row3_col1" class="data row3 col1" >0.2455</td>
#       <td id="T_3f293_row3_col2" class="data row3 col2" >-0.0350</td>
#       <td id="T_3f293_row3_col3" class="data row3 col3" >0.5023</td>
#       <td id="T_3f293_row3_col4" class="data row3 col4" >0.4606</td>
#       <td id="T_3f293_row3_col5" class="data row3 col5" >-0.0417</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row4" class="row_heading level0 row4" >Computer Science</th>
#       <td id="T_3f293_row4_col0" class="data row4 col0" >0.1462</td>
#       <td id="T_3f293_row4_col1" class="data row4 col1" >0.1630</td>
#       <td id="T_3f293_row4_col2" class="data row4 col2" >0.0167</td>
#       <td id="T_3f293_row4_col3" class="data row4 col3" >0.4850</td>
#       <td id="T_3f293_row4_col4" class="data row4 col4" >0.5081</td>
#       <td id="T_3f293_row4_col5" class="data row4 col5" >0.0231</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row5" class="row_heading level0 row5" >Chemistry</th>
#       <td id="T_3f293_row5_col0" class="data row5 col0" >0.0853</td>
#       <td id="T_3f293_row5_col1" class="data row5 col1" >0.2473</td>
#       <td id="T_3f293_row5_col2" class="data row5 col2" >0.1620</td>
#       <td id="T_3f293_row5_col3" class="data row5 col3" >0.4838</td>
#       <td id="T_3f293_row5_col4" class="data row5 col4" >0.4471</td>
#       <td id="T_3f293_row5_col5" class="data row5 col5" >-0.0367</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row6" class="row_heading level0 row6" >Biochemistry, Genetics and Molecular Biology</th>
#       <td id="T_3f293_row6_col0" class="data row6 col0" >0.2278</td>
#       <td id="T_3f293_row6_col1" class="data row6 col1" >0.1650</td>
#       <td id="T_3f293_row6_col2" class="data row6 col2" >-0.0628</td>
#       <td id="T_3f293_row6_col3" class="data row6 col3" >0.4184</td>
#       <td id="T_3f293_row6_col4" class="data row6 col4" >0.3447</td>
#       <td id="T_3f293_row6_col5" class="data row6 col5" >-0.0737</td>
#     </tr>
#     <tr>
#       <th id="T_3f293_level0_row7" class="row_heading level0 row7" >Chemical Engineering</th>
#       <td id="T_3f293_row7_col0" class="data row7 col0" >0.1534</td>
#       <td id="T_3f293_row7_col1" class="data row7 col1" >0.2119</td>
#       <td id="T_3f293_ro

# %%
df_ai_cshared.corr(method='spearman')
# Out:
#                                Pearson (All)  Pearson (Citable)  \
# Pearson (All)                       1.000000           0.939145
# Pearson (Citable)                   0.939145           1.000000
# Pearson Diff (Citable - All)        0.165812           0.457094
# Spearman (All)                      0.874188           0.841368
# Spearman (Citable)                  0.830427           0.836581
# Spearman Diff (Citable - All)      -0.236923          -0.105641
#
#                                Pearson Diff (Citable - All)  Spearman (All)  \
# Pearson (All)                                      0.165812        0.874188
# Pearson (Citable)                                  0.457094        0.841368
# Pearson Diff (Citable - All)                       1.000000        0.173333
# Spearman (All)                                     0.173333        1.000000
# Spearman (Citable)                                 0.301197        0.971966
# Spearman Diff (Citable - All)                      0.543932       -0.134359
#
#                                Spearman (Citable)  \
# Pearson (All)                            0.830427
# Pearson (Citable)                        0.836581
# Pearson Diff (Citable - All)             0.301197
# Spearman (All)                           0.971966
# Spearman (Citable)                       1.000000
# Spearman Diff (Citable - All)            0.055726
#
#                                Spearman Diff (Citable - All)
# Pearson (All)                                      -0.236923
# Pearson (Citable)                                  -0.105641
# Pearson Diff (Citable - All)                        0.543932
# Spearman (All)                                     -0.134359
# Spearman (Citable)                                  0.055726
# Spearman Diff (Citable - All)                       1.000000

# %% [markdown]
# ## 3. F-Measure vs DShareC (ShareC) Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **DShareC**.

# %%
df_f_dsharec = get_comparison_table('F-Measure vs DShareC')
display_styled_table(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'Table 3: F-Measure vs DShareC (All vs. Citable)')
plot_comparison(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'F-Measure vs DShareC (ShareC)')
# Out:
# <style type="text/css">
# #T_bdc8e th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_bdc8e td {
#   text-align: right;
# }
# #T_bdc8e caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_bdc8e_row0_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_bdc8e_row0_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_bdc8e_row1_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_bdc8e_row1_col5 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_bdc8e_row2_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_bdc8e_row2_col5, #T_bdc8e_row19_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_bdc8e_row3_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_bdc8e_row3_col5, #T_bdc8e_row23_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_bdc8e_row4_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bdc8e_row4_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_bdc8e_row5_col2, #T_bdc8e_row11_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_bdc8e_row5_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_bdc8e_row6_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_bdc8e_row6_col5, #T_bdc8e_row8_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_bdc8e_row7_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_bdc8e_row7_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_bdc8e_row8_col5 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_bdc8e_row9_col2, #T_bdc8e_row12_col5, #T_bdc8e_row16_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_bdc8e_row9_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_bdc8e_row10_col2, #T_bdc8e_row19_col5 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_bdc8e_row10_col5 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_bdc8e_row11_col5 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_bdc8e_row12_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_bdc8e_row13_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_bdc8e_row13_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_bdc8e_row14_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_bdc8e_row14_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_bdc8e_row15_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_bdc8e_row15_col5, #T_bdc8e_row21_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_bdc8e_row16_col5 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_bdc8e_row17_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bdc8e_row17_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_bdc8e_row18_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_bdc8e_row18_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_bdc8e_row20_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_bdc8e_row20_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_bdc8e_row21_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_bdc8e_row22_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_bdc8e_row22_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_bdc8e_row23_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_bdc8e_row24_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bdc8e_row24_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_bdc8e_row25_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_bdc8e_row25_col5 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# </style>
# <table id="T_bdc8e" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 3: F-Measure vs DShareC (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdc8e_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_bdc8e_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_bdc8e_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_bdc8e_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_bdc8e_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_bdc8e_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdc8e_level0_row0" class="row_heading level0 row0" >Engineering</th>
#       <td id="T_bdc8e_row0_col0" class="data row0 col0" >0.2737</td>
#       <td id="T_bdc8e_row0_col1" class="data row0 col1" >0.3474</td>
#       <td id="T_bdc8e_row0_col2" class="data row0 col2" >0.0736</td>
#       <td id="T_bdc8e_row0_col3" class="data row0 col3" >0.7193</td>
#       <td id="T_bdc8e_row0_col4" class="data row0 col4" >0.7306</td>
#       <td id="T_bdc8e_row0_col5" class="data row0 col5" >0.0113</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_level0_row1" class="row_heading level0 row1" >Physics and Astronomy</th>
#       <td id="T_bdc8e_row1_col0" class="data row1 col0" >0.2556</td>
#       <td id="T_bdc8e_row1_col1" class="data row1 col1" >0.2584</td>
#       <td id="T_bdc8e_row1_col2" class="data row1 col2" >0.0028</td>
#       <td id="T_bdc8e_row1_col3" class="data row1 col3" >0.6693</td>
#       <td id="T_bdc8e_row1_col4" class="data row1 col4" >0.6889</td>
#       <td id="T_bdc8e_row1_col5" class="data row1 col5" >0.0195</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_level0_row2" class="row_heading level0 row2" >Materials Science</th>
#       <td id="T_bdc8e_row2_col0" class="data row2 col0" >0.3153</td>
#       <td id="T_bdc8e_row2_col1" class="data row2 col1" >0.4316</td>
#       <td id="T_bdc8e_row2_col2" class="data row2 col2" >0.1163</td>
#       <td id="T_bdc8e_row2_col3" class="data row2 col3" >0.6154</td>
#       <td id="T_bdc8e_row2_col4" class="data row2 col4" >0.6422</td>
#       <td id="T_bdc8e_row2_col5" class="data row2 col5" >0.0267</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_level0_row3" class="row_heading level0 row3" >Neuroscience</th>
#       <td id="T_bdc8e_row3_col0" class="data row3 col0" >0.4715</td>
#       <td id="T_bdc8e_row3_col1" class="data row3 col1" >0.4297</td>
#       <td id="T_bdc8e_row3_col2" class="data row3 col2" >-0.0418</td>
#       <td id="T_bdc8e_row3_col3" class="data row3 col3" >0.5377</td>
#       <td id="T_bdc8e_row3_col4" class="data row3 col4" >0.5027</td>
#       <td id="T_bdc8e_row3_col5" class="data row3 col5" >-0.0349</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_level0_row4" class="row_heading level0 row4" >Chemistry</th>
#       <td id="T_bdc8e_row4_col0" class="data row4 col0" >0.1508</td>
#       <td id="T_bdc8e_row4_col1" class="data row4 col1" >0.4675</td>
#       <td id="T_bdc8e_row4_col2" class="data row4 col2" >0.3167</td>
#       <td id="T_bdc8e_row4_col3" class="data row4 col3" >0.5125</td>
#       <td id="T_bdc8e_row4_col4" class="data row4 col4" >0.4807</td>
#       <td id="T_bdc8e_row4_col5" class="data row4 col5" >-0.0318</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_level0_row5" class="row_heading level0 row5" >Computer Science</th>
#       <td id="T_bdc8e_row5_col0" class="data row5 col0" >0.1936</td>
#       <td id="T_bdc8e_row5_col1" class="data row5 col1" >0.2142</td>
#       <td id="T_bdc8e_row5_col2" class="data row5 col2" >0.0206</td>
#       <td id="T_bdc8e_row5_col3" class="data row5 col3" >0.4930</td>
#       <td id="T_bdc8e_row5_col4" class="data row5 col4" >0.5151</td>
#       <td id="T_bdc8e_row5_col5" class="data row5 col5" >0.0221</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_level0_row6" class="row_heading level0 row6" >Chemical Engineering</th>
#       <td id="T_bdc8e_row6_col0" class="data row6 col0" >0.2660</td>
#       <td id="T_bdc8e_row6_col1" class="data row6 col1" >0.3811</td>
#       <td id="T_bdc8e_row6_col2" class="data row6 col2" >0.1151</td>
#       <td id="T_bdc8e_row6_col3" class="data row6 col3" >0.4840</td>
#       <td id="T_bdc8e_row6_col4" class="data row6 col4" >0.5660</td>
#       <td id="T_bdc8e_row6_col5" class="data row6 col5" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8e_leve

# %%
df_f_dsharec.corr(method='spearman')
# Out:
#                                Pearson (All)  Pearson (Citable)  \
# Pearson (All)                       1.000000           0.910427
# Pearson (Citable)                   0.910427           1.000000
# Pearson Diff (Citable - All)        0.244444           0.546667
# Spearman (All)                      0.877607           0.890598
# Spearman (Citable)                  0.840000           0.876923
# Spearman Diff (Citable - All)      -0.124786           0.008547
#
#                                Pearson Diff (Citable - All)  Spearman (All)  \
# Pearson (All)                                      0.244444        0.877607
# Pearson (Citable)                                  0.546667        0.890598
# Pearson Diff (Citable - All)                       1.000000        0.347009
# Spearman (All)                                     0.347009        1.000000
# Spearman (Citable)                                 0.444103        0.972650
# Spearman Diff (Citable - All)                      0.520000       -0.054359
#
#                                Spearman (Citable)  \
# Pearson (All)                            0.840000
# Pearson (Citable)                        0.876923
# Pearson Diff (Citable - All)             0.444103
# Spearman (All)                           0.972650
# Spearman (Citable)                       1.000000
# Spearman Diff (Citable - All)            0.151453
#
#                                Spearman Diff (Citable - All)
# Pearson (All)                                      -0.124786
# Pearson (Citable)                                   0.008547
# Pearson Diff (Citable - All)                        0.520000
# Spearman (All)                                     -0.054359
# Spearman (Citable)                                  0.151453
# Spearman Diff (Citable - All)                       1.000000

# %% [markdown]
# ## 4. F-Measure vs CShareD Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **CShareD**.

# %%
df_f_cshared = get_comparison_table('F-Measure vs CShareD')
display_styled_table(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'Table 4: F-Measure vs CShareD (All vs. Citable)')
plot_comparison(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'F-Measure vs CShareD')
# Out:
# <style type="text/css">
# #T_23c5e th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_23c5e td {
#   text-align: right;
# }
# #T_23c5e caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_23c5e_row0_col2, #T_23c5e_row22_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_23c5e_row0_col5, #T_23c5e_row1_col5, #T_23c5e_row2_col5, #T_23c5e_row3_col5, #T_23c5e_row4_col5, #T_23c5e_row5_col5, #T_23c5e_row7_col5, #T_23c5e_row8_col5, #T_23c5e_row9_col5, #T_23c5e_row10_col5, #T_23c5e_row13_col5, #T_23c5e_row14_col5, #T_23c5e_row15_col5, #T_23c5e_row16_col5, #T_23c5e_row18_col5, #T_23c5e_row19_col5, #T_23c5e_row22_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_23c5e_row1_col2, #T_23c5e_row18_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_23c5e_row2_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_23c5e_row3_col2, #T_23c5e_row17_col5, #T_23c5e_row20_col5, #T_23c5e_row21_col5, #T_23c5e_row24_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_23c5e_row4_col2, #T_23c5e_row25_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_23c5e_row5_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_23c5e_row6_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_23c5e_row6_col5, #T_23c5e_row11_col5, #T_23c5e_row12_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_23c5e_row7_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_23c5e_row8_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_23c5e_row9_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_23c5e_row10_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_23c5e_row11_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_23c5e_row12_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_23c5e_row13_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_23c5e_row14_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_23c5e_row15_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_23c5e_row16_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_23c5e_row17_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_23c5e_row19_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_23c5e_row20_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_23c5e_row21_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_23c5e_row23_col2, #T_23c5e_row24_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_23c5e_row23_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_23c5e_row25_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# </style>
# <table id="T_23c5e" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 4: F-Measure vs CShareD (All vs. Citable)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23c5e_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_23c5e_level0_col1" class="col_heading level0 col1" >Pearson (Citable)</th>
#       <th id="T_23c5e_level0_col2" class="col_heading level0 col2" >Pearson Diff (Citable - All)</th>
#       <th id="T_23c5e_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_23c5e_level0_col4" class="col_heading level0 col4" >Spearman (Citable)</th>
#       <th id="T_23c5e_level0_col5" class="col_heading level0 col5" >Spearman Diff (Citable - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23c5e_level0_row0" class="row_heading level0 row0" >Medicine</th>
#       <td id="T_23c5e_row0_col0" class="data row0 col0" >0.9864</td>
#       <td id="T_23c5e_row0_col1" class="data row0 col1" >0.9815</td>
#       <td id="T_23c5e_row0_col2" class="data row0 col2" >-0.0049</td>
#       <td id="T_23c5e_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_23c5e_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_23c5e_row0_col5" class="data row0 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row1" class="row_heading level0 row1" >Environmental Science</th>
#       <td id="T_23c5e_row1_col0" class="data row1 col0" >0.9123</td>
#       <td id="T_23c5e_row1_col1" class="data row1 col1" >0.8850</td>
#       <td id="T_23c5e_row1_col2" class="data row1 col2" >-0.0273</td>
#       <td id="T_23c5e_row1_col3" class="data row1 col3" >0.9999</td>
#       <td id="T_23c5e_row1_col4" class="data row1 col4" >0.9999</td>
#       <td id="T_23c5e_row1_col5" class="data row1 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row2" class="row_heading level0 row2" >Social Sciences</th>
#       <td id="T_23c5e_row2_col0" class="data row2 col0" >0.9780</td>
#       <td id="T_23c5e_row2_col1" class="data row2 col1" >0.9869</td>
#       <td id="T_23c5e_row2_col2" class="data row2 col2" >0.0089</td>
#       <td id="T_23c5e_row2_col3" class="data row2 col3" >0.9999</td>
#       <td id="T_23c5e_row2_col4" class="data row2 col4" >0.9999</td>
#       <td id="T_23c5e_row2_col5" class="data row2 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row3" class="row_heading level0 row3" >Engineering</th>
#       <td id="T_23c5e_row3_col0" class="data row3 col0" >0.9864</td>
#       <td id="T_23c5e_row3_col1" class="data row3 col1" >0.9838</td>
#       <td id="T_23c5e_row3_col2" class="data row3 col2" >-0.0026</td>
#       <td id="T_23c5e_row3_col3" class="data row3 col3" >0.9999</td>
#       <td id="T_23c5e_row3_col4" class="data row3 col4" >0.9999</td>
#       <td id="T_23c5e_row3_col5" class="data row3 col5" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row4" class="row_heading level0 row4" >Computer Science</th>
#       <td id="T_23c5e_row4_col0" class="data row4 col0" >0.9567</td>
#       <td id="T_23c5e_row4_col1" class="data row4 col1" >0.9418</td>
#       <td id="T_23c5e_row4_col2" class="data row4 col2" >-0.0149</td>
#       <td id="T_23c5e_row4_col3" class="data row4 col3" >0.9999</td>
#       <td id="T_23c5e_row4_col4" class="data row4 col4" >0.9998</td>
#       <td id="T_23c5e_row4_col5" class="data row4 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row5" class="row_heading level0 row5" >Agricultural and Biological Sciences</th>
#       <td id="T_23c5e_row5_col0" class="data row5 col0" >0.9034</td>
#       <td id="T_23c5e_row5_col1" class="data row5 col1" >0.9050</td>
#       <td id="T_23c5e_row5_col2" class="data row5 col2" >0.0016</td>
#       <td id="T_23c5e_row5_col3" class="data row5 col3" >0.9998</td>
#       <td id="T_23c5e_row5_col4" class="data row5 col4" >0.9996</td>
#       <td id="T_23c5e_row5_col5" class="data row5 col5" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row6" class="row_heading level0 row6" >Biochemistry, Genetics and Molecular Biology</th>
#       <td id="T_23c5e_row6_col0" class="data row6 col0" >0.9306</td>
#       <td id="T_23c5e_row6_col1" class="data row6 col1" >0.8962</td>
#       <td id="T_23c5e_row6_col2" class="data row6 col2" >-0.0343</td>
#       <td id="T_23c5e_row6_col3" class="data row6 col3" >0.9997</td>
#       <td id="T_23c5e_row6_col4" class="data row6 col4" >0.9997</td>
#       <td id="T_23c5e_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row7" class="row_heading level0 row7" >Psychology</th>
#       <td id="T_23c5e_row7_col0" class="data row7 col0" >0.8596</td>
#       <td id="T_23c5e_row7_col1" class="data row7 col1" >0.8335</td>
#       <td id="T_23c5e_row7_col2" class="data row7 col2" >-0.0260</td>
#       <td id="T_23c5e_row7_col3" class="data row7 col3" >0.9996</td>
#       <td id="T_23c5e_row7_col4" class="data row7 col4" >0.9995</td>
#       <td id="T_23c5e_row7_col5" class="data row7 col5" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_23c5e_level0_row8" class="row_heading level0 row8" >Health Professions</th>
#       <td id="T_23c5e_row8_col0" class="data row8 col0" >0.8588</td>
#       <td id="T_23c5e_row8_col1" class="data row8 col1" >0.8642</td>
#       <td id="T_23c5e_row8_col2" class="data row8 col2" >0.0054</td>
#       <td id="T_23c5e_row8_col3" class="data row8 col3"

# %% [markdown]
# ## 5. Summary Statistics and Overall Analysis (Absolute Discrepancies)
#
# To synthesize the comparison, let's look at the summary statistics of the **absolute differences** across all 22 OpenAlex Fields for each of the four indicator pairs.
#
# Using absolute values is essential because it measures the magnitude of the discrepancy (change) regardless of whether the correlation went up or down. For example, a large negative change like -0.76708 represents a major discrepancy of 0.76708 in absolute terms. Computing statistics on signed differences can cause positive and negative changes to cancel each other out, hiding the true extent of the changes.

# %%
summary_data = []
pairs_mapping = {
    'AI vs DShareC': 'AI vs DShareC',
    'AI vs CShareD': 'AI vs CShareD',
    'F-Measure vs DShareC': 'F-Measure vs DShareC',
    'F-Measure vs CShareD': 'F-Measure vs CShareD'
}

for user_name, csv_name in pairs_mapping.items():
    df_p = get_comparison_table(csv_name)
    pearson_abs = df_p['Pearson Diff (Citable - All)'].abs()
    spearman_abs = df_p['Spearman Diff (Citable - All)'].abs()
    summary_data.append({
        'Indicator Pair': user_name,
        'Mean Abs Pearson Diff': pearson_abs.mean(),
        'Median Abs Pearson Diff': pearson_abs.median(),
        'Max Abs Pearson Diff': pearson_abs.max(),
        'Min Abs Pearson Diff': pearson_abs.min(),
        'Mean Abs Spearman Diff': spearman_abs.mean(),
        'Median Abs Spearman Diff': spearman_abs.median(),
        'Max Abs Spearman Diff': spearman_abs.max(),
        'Min Abs Spearman Diff': spearman_abs.min()
    })

df_summary = pd.DataFrame(summary_data).set_index('Indicator Pair')

styled_summary = df_summary.style.format("{:.5f}")\
    .background_gradient(cmap="Reds", vmin=0.0, vmax=0.3)\
    .set_caption("<b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|Citable - All|)</b>")\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#2c3e50'), ('color', 'white'), ('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('text-align', 'right')]},
        {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
    ])
display(styled_summary)
global text
text = text + "<h2>Overall Comparison Summary</h2>" + styled_summary.to_html() + "<br><br>"
# Out:
# <style type="text/css">
# #T_bb7a6 th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_bb7a6 td {
#   text-align: right;
# }
# #T_bb7a6 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_bb7a6_row0_col0, #T_bb7a6_row0_col1, #T_bb7a6_row0_col2, #T_bb7a6_row0_col3, #T_bb7a6_row0_col4, #T_bb7a6_row0_col5, #T_bb7a6_row0_col6, #T_bb7a6_row0_col7, #T_bb7a6_row3_col5, #T_bb7a6_row3_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_bb7a6_row1_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_bb7a6_row1_col1, #T_bb7a6_row3_col0 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_bb7a6_row1_col2 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_bb7a6_row1_col3 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_bb7a6_row1_col4 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_bb7a6_row1_col5 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_bb7a6_row1_col6 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_bb7a6_row1_col7 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_bb7a6_row2_col0 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_bb7a6_row2_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_bb7a6_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_bb7a6_row2_col3, #T_bb7a6_row3_col3, #T_bb7a6_row3_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_bb7a6_row2_col4 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_bb7a6_row2_col5 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_bb7a6_row2_col6 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_bb7a6_row2_col7 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_bb7a6_row3_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_bb7a6_row3_col2 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_bb7a6_row3_col6 {
#   background-color: #fee9df;
#   color: #000000;
# }
# </style>
# <table id="T_bb7a6" class="dataframe">
#   <caption><b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|Citable - All|)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb7a6_level0_col0" class="col_heading level0 col0" >Mean Abs Pearson Diff</th>
#       <th id="T_bb7a6_level0_col1" class="col_heading level0 col1" >Median Abs Pearson Diff</th>
#       <th id="T_bb7a6_level0_col2" class="col_heading level0 col2" >Max Abs Pearson Diff</th>
#       <th id="T_bb7a6_level0_col3" class="col_heading level0 col3" >Min Abs Pearson Diff</th>
#       <th id="T_bb7a6_level0_col4" class="col_heading level0 col4" >Mean Abs Spearman Diff</th>
#       <th id="T_bb7a6_level0_col5" class="col_heading level0 col5" >Median Abs Spearman Diff</th>
#       <th id="T_bb7a6_level0_col6" class="col_heading level0 col6" >Max Abs Spearman Diff</th>
#       <th id="T_bb7a6_level0_col7" class="col_heading level0 col7" >Min Abs Spearman Diff</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator Pair</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb7a6_level0_row0" class="row_heading level0 row0" >AI vs DShareC</th>
#       <td id="T_bb7a6_row0_col0" class="data row0 col0" >0.00000</td>
#       <td id="T_bb7a6_row0_col1" class="data row0 col1" >0.00000</td>
#       <td id="T_bb7a6_row0_col2" class="data row0 col2" >0.00000</td>
#       <td id="T_bb7a6_row0_col3" class="data row0 col3" >0.00000</td>
#       <td id="T_bb7a6_row0_col4" class="data row0 col4" >0.00000</td>
#       <td id="T_bb7a6_row0_col5" class="data row0 col5" >0.00000</td>
#       <td id="T_bb7a6_row0_col6" class="data row0 col6" >0.00000</td>
#       <td id="T_bb7a6_row0_col7" class="data row0 col7" >0.00000</td>
#     </tr>
#     <tr>
#       <th id="T_bb7a6_level0_row1" class="row_heading level0 row1" >AI vs CShareD</th>
#       <td id="T_bb7a6_row1_col0" class="data row1 col0" >0.04049</td>
#       <td id="T_bb7a6_row1_col1" class="data row1 col1" >0.02938</td>
#       <td id="T_bb7a6_row1_col2" class="data row1 col2" >0.16201</td>
#       <td id="T_bb7a6_row1_col3" class="data row1 col3" >0.00636</td>
#       <td id="T_bb7a6_row1_col4" class="data row1 col4" >0.04613</td>
#       <td id="T_bb7a6_row1_col5" class="data row1 col5" >0.03742</td>
#       <td id="T_bb7a6_row1_col6" class="data row1 col6" >0.14427</td>
#       <td id="T_bb7a6_row1_col7" class="data row1 col7" >0.00780</td>
#     </tr>
#     <tr>
#       <th id="T_bb7a6_level0_row2" class="row_heading level0 row2" >F-Measure vs DShareC</th>
#       <td id="T_bb7a6_row2_col0" class="data row2 col0" >0.06311</td>
#       <td id="T_bb7a6_row2_col1" class="data row2 col1" >0.05347</td>
#       <td id="T_bb7a6_row2_col2" class="data row2 col2" >0.31668</td>
#       <td id="T_bb7a6_row2_col3" class="data row2 col3" >0.00202</td>
#       <td id="T_bb7a6_row2_col4" class="data row2 col4" >0.04754</td>
#       <td id="T_bb7a6_row2_col5" class="data row2 col5" >0.03477</td>
#       <td id="T_bb7a6_row2_col6" class="data row2 col6" >0.13842</td>
#       <td id="T_bb7a6_row2_col7" class="data row2 col7" >0.00325</td>
#     </tr>
#     <tr>
#       <th id="T_bb7a6_level0_row3" class="row_heading level0 row3" >F-Measure vs CShareD</th>
#       <td id="T_bb7a6_row3_col0" class="data row3 col0" >0.03001</td>
#       <td id="T_bb7a6_row3_col1" class="data row3 col1" >0.02633</td>
#       <td id="T_bb7a6_row3_col2" class="data row3 col2" >0.13083</td>
#       <td id="T_bb7a6_row3_col3" class="data row3 col3" >0.00157</td>
#       <td id="T_bb7a6_row3_col4" class="data row3 col4" >0.00172</td>
#       <td id="T_bb7a6_row3_col5" class="data row3 col5" >0.00050</td>
#       <td id="T_bb7a6_row3_col6" class="data row3 col6" >0.02137</td>
#       <td id="T_bb7a6_row3_col7" class="data row3 col7" >0.00000</td>
#     </tr>
#   </tbody>
# </table>

# %%
global text
text = text + "</body></html>"
with open("All_vs_Citable Documents.html", "w", encoding="utf-8") as f:
    f.write(text)
print("Saved report to All_vs_Citable Documents.html")
# Out:
# Saved report to All_vs_Citable Documents.html
