# %% [markdown]
# # Comparison of Global Context Correlations: All Units vs. 50 Units
#
# This notebook performs a systematic comparison between the correlations calculated for **All Units** and **50 Units** in the Global Context across different  OpenAlex Topics.

# %%
#Montar mi google drive para poder usar los archivos
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext - 50/"
# !ls
# Out:
# /content/gdrive/.shortcut-targets-by-id/0B5aSrRJgnViLfm9LWl9TY21TWm5wSU0zbkgzc2YyeEp3RzJMaEJOR2FWbFkxVEZYTjNQd1E/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext - 50
# '50_vs_100 Units.html'
#  ai.txt
#  AMEASURE.txt
#  figuras
#  FMEASURE.txt
#  GAggregation.txt
#  GMEASURE.txt
#  ManuscriptActivityIndexFmeasure_ESI_GlobalContext.ipynb
#  manuscriptFiguresAndTables.html
#  pearson_correlation_AI_FMeasure.csv
#  rsi.txt
#  scatterplots
#  scatterplots.html
#  share.txt
#  spearman_correlation_2024.csv
#  Spearman_correlation_AI_FMeasure.csv
#  Wshare.txt

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Set plotting style
sns.set_theme(style="whitegrid")
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['DejaVu Sans', 'Arial', 'Helvetica'],
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'figure.titlesize': 14,
    'figure.titleweight': 'bold'
})


# Initialize HTML report container
text = """
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>Comparison Analysis Report</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; color: #2c3e50; }
        h1, h2, h3 { color: #2c3e50; }
        table { border-collapse: collapse; width: 100%; margin-bottom: 20px; }
        th, td { border: 1px solid #bdc3c7; padding: 8px; text-align: left; }
        th { background-color: #f4f6f7; font-weight: bold; }
        img { max-width: 100%; height: auto; display: block; margin: 20px 0; }
    </style>
</head>
<body>
<h1>Comparison Analysis Report (All vs. 50 Units)</h1>
"""

# %%
# Define paths to the CSV files
paths = {
    'all_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext/pearson_correlation_AI_FMeasure.csv',
    'all_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext/Spearman_correlation_AI_FMeasure.csv',
    '50_pearson': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext - 50/pearson_correlation_AI_FMeasure.csv',
    '50_spearman': r'/content/gdrive/My Drive/Ciencias/Data/WoS/InCites/ESI/ManuscriptExperiments - subir/Citable_Documents/OpenAlex/GlobalContext - 50/Spearman_correlation_AI_FMeasure.csv'
}

# Load files
dfs = {}
for name, path in paths.items():
    if not os.path.exists(path):
        # Try relative paths as fallback
        if '2026' in path:
            rel_path = f'Global Context/{os.path.basename(path)}'
        else:
            rel_path = f'../../ManuscriptExperiments/Global Context/{os.path.basename(path)}'
        if os.path.exists(rel_path):
            path = rel_path

    dfs[name] = pd.read_csv(path, index_col=0)
    print(f"Successfully loaded {name} (Shape: {dfs[name].shape})")
# Out:
# Successfully loaded all_pearson (Shape: (26, 11))
# Successfully loaded all_spearman (Shape: (26, 11))
# Successfully loaded 50_pearson (Shape: (26, 11))
# Successfully loaded 50_spearman (Shape: (26, 11))

# %%
def get_comparison_table(col_name):
    """
    Creates a side-by-side comparison table for a specific correlation column.
    """
    # Base index of OpenAlex Fields from the Pearson All dataset
    index_ref = dfs['all_pearson'].index

    df_comp = pd.DataFrame(index=index_ref)

    # Pearson
    df_comp['Pearson (All)'] = dfs['all_pearson'][col_name]
    df_comp['Pearson (50)'] = dfs['50_pearson'][col_name]
    df_comp['Pearson Diff (50 - All)'] = df_comp['Pearson (50)'] - df_comp['Pearson (All)']

    # Spearman (aligning indices)
    df_comp['Spearman (All)'] = df_comp.index.map(dfs['all_spearman'][col_name])
    df_comp['Spearman (50)'] = df_comp.index.map(dfs['50_spearman'][col_name])
    df_comp['Spearman Diff (50 - All)'] = df_comp['Spearman (50)'] - df_comp['Spearman (All)']

    # Sort OpenAlex Fields alphabetically
    df_comp = df_comp.sort_index()
    return df_comp

def display_styled_table(df, title):
    """
    Applies advanced pandas styler to color-code difference columns and display.
    """
    styled = df.style.format("{:.4f}")\
        .background_gradient(cmap="coolwarm", subset=["Pearson Diff (50 - All)", "Spearman Diff (50 - All)"], vmin=-0.2, vmax=0.2)\
        .set_caption(f"<b style='font-size: 14px;'>{title}</b>")\
        .set_table_styles([
            {'selector': 'th', 'props': [('background-color', '#f4f6f7'), ('color', '#2c3e50'), ('font-weight', 'bold'), ('text-align', 'center')]},
            {'selector': 'td', 'props': [('text-align', 'right')]},
            {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
        ])
    display(styled)
    global text
    text = text + f"<h2>{title}</h2>" + styled.to_html() + "<br><br>"

def plot_comparison(df, user_name):
    """
    Generates side-by-side horizontal bar plots to visualize the differences in correlations.
    """
    # Prepare Pearson data for Seaborn
    df_pearson = pd.DataFrame({
        'OpenAlex Field': df.index,
        'All Units': df['Pearson (All)'].values,
        '50 Units': df['Pearson (50)'].values
    }).melt(id_vars='OpenAlex Field', var_name='Dataset', value_name='Pearson Correlation')

    # Prepare Spearman data for Seaborn
    df_spearman = pd.DataFrame({
        'OpenAlex Field': df.index,
        'All Units': df['Spearman (All)'].values,
        '50 Units': df['Spearman (50)'].values
    }).melt(id_vars='OpenAlex Field', var_name='Dataset', value_name='Spearman Correlation')

    fig, axes = plt.subplots(1, 2, figsize=(16, 9), sharey=True)

    # Harmonious colors: Cool Blue for All, Warm Coral for 50
    colors = {'All Units': '#2b7bba', '50 Units': '#e76f51'}

    # Pearson Subplot
    sns.barplot(
        data=df_pearson,
        y='OpenAlex Field',
        x='Pearson Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[0]
    )
    axes[0].set_title("Pearson Correlation Coefficient", fontsize=13, pad=10)
    axes[0].set_xlabel("Correlation Value")
    axes[0].set_ylabel("OpenAlex Field")
    axes[0].set_xlim(-1.05, 1.05)
    axes[0].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[0].legend().set_visible(False)

    # Spearman Subplot
    sns.barplot(
        data=df_spearman,
        y='OpenAlex Field',
        x='Spearman Correlation',
        hue='Dataset',
        palette=colors,
        ax=axes[1]
    )
    axes[1].set_title("Spearman Correlation Coefficient", fontsize=13, pad=10)
    axes[1].set_xlabel("Correlation Value")
    axes[1].set_ylabel("")
    axes[1].set_xlim(-1.05, 1.05)
    axes[1].grid(True, linestyle="--", alpha=0.6, axis='x')
    axes[1].legend().set_visible(False)

    # Add single common legend
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.97), ncol=2, fontsize=11)

    plt.suptitle(f"Correlation Comparison: {user_name} (All vs. 50)", fontsize=15, y=1.03)
    plt.tight_layout()
    import os
    os.makedirs('figuras', exist_ok=True)
    fig_name_clean = user_name.replace(' ', '_').replace('/', '_').replace(':', '_').replace('(', '').replace(')', '')
    fig_filename = f"figuras/comparison_{fig_name_clean}.png"
    plt.savefig(fig_filename, bbox_inches='tight')
    global text
    text = text + f"<img src='{fig_filename}' alt='{user_name} Comparison'><br><br>\n"
    plt.show()

# %% [markdown]
# ## 1. AI vs DShareC Correlation Comparison
#
# This section compares the Pearson and Spearman correlations of **Activity Index (AI)** versus **DShareC**.
# This indicator measures how the proportion of publications (AI) relates to the document share in the citation distribution.

# %%
df_ai_dsharec = get_comparison_table('AI vs DShareC')
display_styled_table(df_ai_dsharec, 'Table 1: AI vs DShareC (All vs. 50)')
plot_comparison(df_ai_dsharec, 'AI vs DShareC')
# Out:
# <style type="text/css">
# #T_54e1b th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_54e1b td {
#   text-align: right;
# }
# #T_54e1b caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_54e1b_row0_col2, #T_54e1b_row0_col5, #T_54e1b_row1_col2, #T_54e1b_row1_col5, #T_54e1b_row2_col2, #T_54e1b_row2_col5, #T_54e1b_row3_col5, #T_54e1b_row4_col2, #T_54e1b_row4_col5, #T_54e1b_row5_col2, #T_54e1b_row5_col5, #T_54e1b_row6_col2, #T_54e1b_row6_col5, #T_54e1b_row7_col5, #T_54e1b_row8_col5, #T_54e1b_row9_col5, #T_54e1b_row10_col5, #T_54e1b_row11_col5, #T_54e1b_row12_col2, #T_54e1b_row12_col5, #T_54e1b_row13_col5, #T_54e1b_row14_col2, #T_54e1b_row14_col5, #T_54e1b_row15_col2, #T_54e1b_row15_col5, #T_54e1b_row16_col2, #T_54e1b_row16_col5, #T_54e1b_row17_col2, #T_54e1b_row17_col5, #T_54e1b_row18_col2, #T_54e1b_row18_col5, #T_54e1b_row19_col2, #T_54e1b_row19_col5, #T_54e1b_row20_col2, #T_54e1b_row20_col5, #T_54e1b_row21_col5, #T_54e1b_row22_col2, #T_54e1b_row22_col5, #T_54e1b_row23_col2, #T_54e1b_row23_col5, #T_54e1b_row24_col2, #T_54e1b_row24_col5, #T_54e1b_row25_col2, #T_54e1b_row25_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_54e1b_row3_col2, #T_54e1b_row7_col2, #T_54e1b_row8_col2, #T_54e1b_row9_col2, #T_54e1b_row10_col2, #T_54e1b_row11_col2, #T_54e1b_row13_col2, #T_54e1b_row21_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_54e1b" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 1: AI vs DShareC (All vs. 50)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54e1b_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_54e1b_level0_col1" class="col_heading level0 col1" >Pearson (50)</th>
#       <th id="T_54e1b_level0_col2" class="col_heading level0 col2" >Pearson Diff (50 - All)</th>
#       <th id="T_54e1b_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_54e1b_level0_col4" class="col_heading level0 col4" >Spearman (50)</th>
#       <th id="T_54e1b_level0_col5" class="col_heading level0 col5" >Spearman Diff (50 - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54e1b_level0_row0" class="row_heading level0 row0" >Agricultural and Biological Sciences</th>
#       <td id="T_54e1b_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_54e1b_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_54e1b_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_54e1b_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_54e1b_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_54e1b_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row1" class="row_heading level0 row1" >Arts and Humanities</th>
#       <td id="T_54e1b_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_54e1b_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_54e1b_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_54e1b_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_54e1b_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_54e1b_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row2" class="row_heading level0 row2" >Biochemistry, Genetics and Molecular Biology</th>
#       <td id="T_54e1b_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_54e1b_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_54e1b_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_54e1b_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_54e1b_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_54e1b_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row3" class="row_heading level0 row3" >Business, Management and Accounting</th>
#       <td id="T_54e1b_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_54e1b_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_54e1b_row3_col2" class="data row3 col2" >-0.0000</td>
#       <td id="T_54e1b_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_54e1b_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_54e1b_row3_col5" class="data row3 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row4" class="row_heading level0 row4" >Chemical Engineering</th>
#       <td id="T_54e1b_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_54e1b_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_54e1b_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_54e1b_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_54e1b_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_54e1b_row4_col5" class="data row4 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row5" class="row_heading level0 row5" >Chemistry</th>
#       <td id="T_54e1b_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_54e1b_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_54e1b_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_54e1b_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_54e1b_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_54e1b_row5_col5" class="data row5 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row6" class="row_heading level0 row6" >Computer Science</th>
#       <td id="T_54e1b_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_54e1b_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_54e1b_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_54e1b_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_54e1b_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_54e1b_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row7" class="row_heading level0 row7" >Decision Sciences</th>
#       <td id="T_54e1b_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_54e1b_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_54e1b_row7_col2" class="data row7 col2" >-0.0000</td>
#       <td id="T_54e1b_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_54e1b_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_54e1b_row7_col5" class="data row7 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row8" class="row_heading level0 row8" >Dentistry</th>
#       <td id="T_54e1b_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_54e1b_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_54e1b_row8_col2" class="data row8 col2" >-0.0000</td>
#       <td id="T_54e1b_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_54e1b_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_54e1b_row8_col5" class="data row8 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row9" class="row_heading level0 row9" >Earth and Planetary Sciences</th>
#       <td id="T_54e1b_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_54e1b_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_54e1b_row9_col2" class="data row9 col2" >-0.0000</td>
#       <td id="T_54e1b_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_54e1b_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_54e1b_row9_col5" class="data row9 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_54e1b_level0_row10" class="row_heading level0 row10" >Economics, Econometrics and Finance</th>
#       <td id="T_54e1b_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_54e1b_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_54e1b_row10_col2" class="data row10 col2" >-0.0000</td>
#       <td id="T_54e1b_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_54e1b_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_54e1b_row10_col5" class="d

# %% [markdown]
# ## 2. AI vs CShareD Correlation Comparison
#
# This section compares the correlations of **Activity Index (AI)** versus **CShareD**.

# %%
df_ai_cshared = get_comparison_table('AI vs CShareD')
display_styled_table(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'Table 2: AI vs CShareD (All vs. 50)')
plot_comparison(df_ai_cshared.sort_values('Spearman (All)', ascending=False), 'AI vs CShareD')
# Out:
# <style type="text/css">
# #T_be060 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_be060 td {
#   text-align: right;
# }
# #T_be060 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_be060_row0_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_be060_row0_col5, #T_be060_row3_col5, #T_be060_row12_col5, #T_be060_row14_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_be060_row1_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_be060_row1_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_be060_row2_col2, #T_be060_row6_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_be060_row2_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_be060_row3_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_be060_row4_col2 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_be060_row4_col5 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_be060_row5_col2 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_be060_row5_col5 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_be060_row6_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_be060_row7_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_be060_row7_col5 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_be060_row8_col2, #T_be060_row15_col5 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_be060_row8_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_be060_row9_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_be060_row9_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_be060_row10_col2, #T_be060_row11_col5 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_be060_row10_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_be060_row11_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_be060_row12_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_be060_row13_col2, #T_be060_row18_col5 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_be060_row13_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_be060_row14_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_be060_row15_col2 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_be060_row16_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_be060_row16_col5 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_be060_row17_col2 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_be060_row17_col5, #T_be060_row19_col2, #T_be060_row20_col2, #T_be060_row20_col5, #T_be060_row21_col5, #T_be060_row22_col2, #T_be060_row22_col5, #T_be060_row23_col5, #T_be060_row24_col5, #T_be060_row25_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_be060_row18_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_be060_row19_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_be060_row21_col2 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_be060_row23_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_be060_row24_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_be060_row25_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_be060" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 2: AI vs CShareD (All vs. 50)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be060_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_be060_level0_col1" class="col_heading level0 col1" >Pearson (50)</th>
#       <th id="T_be060_level0_col2" class="col_heading level0 col2" >Pearson Diff (50 - All)</th>
#       <th id="T_be060_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_be060_level0_col4" class="col_heading level0 col4" >Spearman (50)</th>
#       <th id="T_be060_level0_col5" class="col_heading level0 col5" >Spearman Diff (50 - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be060_level0_row0" class="row_heading level0 row0" >Engineering</th>
#       <td id="T_be060_row0_col0" class="data row0 col0" >0.2921</td>
#       <td id="T_be060_row0_col1" class="data row0 col1" >0.3178</td>
#       <td id="T_be060_row0_col2" class="data row0 col2" >0.0258</td>
#       <td id="T_be060_row0_col3" class="data row0 col3" >0.7270</td>
#       <td id="T_be060_row0_col4" class="data row0 col4" >0.4366</td>
#       <td id="T_be060_row0_col5" class="data row0 col5" >-0.2903</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row1" class="row_heading level0 row1" >Physics and Astronomy</th>
#       <td id="T_be060_row1_col0" class="data row1 col0" >0.1234</td>
#       <td id="T_be060_row1_col1" class="data row1 col1" >0.1636</td>
#       <td id="T_be060_row1_col2" class="data row1 col2" >0.0402</td>
#       <td id="T_be060_row1_col3" class="data row1 col3" >0.6636</td>
#       <td id="T_be060_row1_col4" class="data row1 col4" >0.5219</td>
#       <td id="T_be060_row1_col5" class="data row1 col5" >-0.1416</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row2" class="row_heading level0 row2" >Materials Science</th>
#       <td id="T_be060_row2_col0" class="data row2 col0" >0.2550</td>
#       <td id="T_be060_row2_col1" class="data row2 col1" >0.3037</td>
#       <td id="T_be060_row2_col2" class="data row2 col2" >0.0487</td>
#       <td id="T_be060_row2_col3" class="data row2 col3" >0.6240</td>
#       <td id="T_be060_row2_col4" class="data row2 col4" >0.5138</td>
#       <td id="T_be060_row2_col5" class="data row2 col5" >-0.1101</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row3" class="row_heading level0 row3" >Computer Science</th>
#       <td id="T_be060_row3_col0" class="data row3 col0" >0.1630</td>
#       <td id="T_be060_row3_col1" class="data row3 col1" >0.2065</td>
#       <td id="T_be060_row3_col2" class="data row3 col2" >0.0435</td>
#       <td id="T_be060_row3_col3" class="data row3 col3" >0.5081</td>
#       <td id="T_be060_row3_col4" class="data row3 col4" >0.2909</td>
#       <td id="T_be060_row3_col5" class="data row3 col5" >-0.2172</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row4" class="row_heading level0 row4" >Neuroscience</th>
#       <td id="T_be060_row4_col0" class="data row4 col0" >0.2455</td>
#       <td id="T_be060_row4_col1" class="data row4 col1" >0.3591</td>
#       <td id="T_be060_row4_col2" class="data row4 col2" >0.1137</td>
#       <td id="T_be060_row4_col3" class="data row4 col3" >0.4606</td>
#       <td id="T_be060_row4_col4" class="data row4 col4" >0.6471</td>
#       <td id="T_be060_row4_col5" class="data row4 col5" >0.1865</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row5" class="row_heading level0 row5" >Chemical Engineering</th>
#       <td id="T_be060_row5_col0" class="data row5 col0" >0.2119</td>
#       <td id="T_be060_row5_col1" class="data row5 col1" >0.3675</td>
#       <td id="T_be060_row5_col2" class="data row5 col2" >0.1556</td>
#       <td id="T_be060_row5_col3" class="data row5 col3" >0.4503</td>
#       <td id="T_be060_row5_col4" class="data row5 col4" >0.5801</td>
#       <td id="T_be060_row5_col5" class="data row5 col5" >0.1297</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row6" class="row_heading level0 row6" >Chemistry</th>
#       <td id="T_be060_row6_col0" class="data row6 col0" >0.2473</td>
#       <td id="T_be060_row6_col1" class="data row6 col1" >0.2972</td>
#       <td id="T_be060_row6_col2" class="data row6 col2" >0.0499</td>
#       <td id="T_be060_row6_col3" class="data row6 col3" >0.4471</td>
#       <td id="T_be060_row6_col4" class="data row6 col4" >0.4409</td>
#       <td id="T_be060_row6_col5" class="data row6 col5" >-0.0062</td>
#     </tr>
#     <tr>
#       <th id="T_be060_level0_row7" class="row_heading level0 row7" >Mathematics</th>
#       <td id="T_be060_row7_col0" class="data row7 col0" >0.0196</td>
#       <td id="T_be060_row7_col1" class="data row7 col1" >-0.0159</td>
#       <td id="T_be060_row7_col2" class="data row7 col2" >-0.0355</td>
#       <td id="T_be060_row7_col3" class="data row7 col3" >0.3967</td>
#       <td id="T_be060_row7_col4" class="data row7 col4" >0.3472</td>
#       <td id="T_be060_ro

# %%
df_ai_cshared.corr(method='spearman')
# Out:
#                           Pearson (All)  Pearson (50)  \
# Pearson (All)                  1.000000      0.845470
# Pearson (50)                   0.845470      1.000000
# Pearson Diff (50 - All)       -0.135043      0.370256
# Spearman (All)                 0.836581      0.498120
# Spearman (50)                  0.438632      0.407179
# Spearman Diff (50 - All)      -0.584957     -0.234188
#
#                           Pearson Diff (50 - All)  Spearman (All)  \
# Pearson (All)                           -0.135043        0.836581
# Pearson (50)                             0.370256        0.498120
# Pearson Diff (50 - All)                  1.000000       -0.500171
# Spearman (All)                          -0.500171        1.000000
# Spearman (50)                            0.063932        0.504274
# Spearman Diff (50 - All)                 0.605470       -0.712821
#
#                           Spearman (50)  Spearman Diff (50 - All)
# Pearson (All)                  0.438632                 -0.584957
# Pearson (50)                   0.407179                 -0.234188
# Pearson Diff (50 - All)        0.063932                  0.605470
# Spearman (All)                 0.504274                 -0.712821
# Spearman (50)                  1.000000                  0.195214
# Spearman Diff (50 - All)       0.195214                  1.000000

# %% [markdown]
# ## 3. F-Measure vs DShareC (ShareC) Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **DShareC**.

# %%
df_f_dsharec = get_comparison_table('F-Measure vs DShareC')
display_styled_table(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'Table 3: F-Measure vs DShareC (All vs. 50)')
plot_comparison(df_f_dsharec.sort_values('Spearman (All)', ascending=False), 'F-Measure vs DShareC (ShareC)')
# Out:
# <style type="text/css">
# #T_66b39 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_66b39 td {
#   text-align: right;
# }
# #T_66b39 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_66b39_row0_col2, #T_66b39_row12_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_66b39_row0_col5, #T_66b39_row4_col5, #T_66b39_row14_col5, #T_66b39_row16_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_66b39_row1_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_66b39_row1_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_66b39_row2_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_66b39_row2_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_66b39_row3_col2, #T_66b39_row5_col2, #T_66b39_row8_col2, #T_66b39_row9_col2, #T_66b39_row9_col5, #T_66b39_row10_col2, #T_66b39_row11_col2, #T_66b39_row11_col5, #T_66b39_row12_col2, #T_66b39_row13_col2, #T_66b39_row15_col2, #T_66b39_row15_col5, #T_66b39_row17_col2, #T_66b39_row19_col2, #T_66b39_row19_col5, #T_66b39_row20_col2, #T_66b39_row21_col2, #T_66b39_row21_col5, #T_66b39_row22_col2, #T_66b39_row22_col5, #T_66b39_row23_col2, #T_66b39_row23_col5, #T_66b39_row24_col5, #T_66b39_row25_col2, #T_66b39_row25_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_66b39_row3_col5 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_66b39_row4_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_66b39_row5_col5 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_66b39_row6_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_66b39_row6_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_66b39_row7_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_66b39_row7_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_66b39_row8_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_66b39_row10_col5 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_66b39_row13_col5, #T_66b39_row18_col5 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_66b39_row14_col2 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_66b39_row16_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_66b39_row17_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_66b39_row18_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_66b39_row20_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_66b39_row24_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66b39" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 3: F-Measure vs DShareC (All vs. 50)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66b39_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_66b39_level0_col1" class="col_heading level0 col1" >Pearson (50)</th>
#       <th id="T_66b39_level0_col2" class="col_heading level0 col2" >Pearson Diff (50 - All)</th>
#       <th id="T_66b39_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_66b39_level0_col4" class="col_heading level0 col4" >Spearman (50)</th>
#       <th id="T_66b39_level0_col5" class="col_heading level0 col5" >Spearman Diff (50 - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66b39_level0_row0" class="row_heading level0 row0" >Engineering</th>
#       <td id="T_66b39_row0_col0" class="data row0 col0" >0.3474</td>
#       <td id="T_66b39_row0_col1" class="data row0 col1" >0.3520</td>
#       <td id="T_66b39_row0_col2" class="data row0 col2" >0.0047</td>
#       <td id="T_66b39_row0_col3" class="data row0 col3" >0.7306</td>
#       <td id="T_66b39_row0_col4" class="data row0 col4" >0.4456</td>
#       <td id="T_66b39_row0_col5" class="data row0 col5" >-0.2850</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row1" class="row_heading level0 row1" >Physics and Astronomy</th>
#       <td id="T_66b39_row1_col0" class="data row1 col0" >0.2584</td>
#       <td id="T_66b39_row1_col1" class="data row1 col1" >0.4061</td>
#       <td id="T_66b39_row1_col2" class="data row1 col2" >0.1477</td>
#       <td id="T_66b39_row1_col3" class="data row1 col3" >0.6889</td>
#       <td id="T_66b39_row1_col4" class="data row1 col4" >0.5864</td>
#       <td id="T_66b39_row1_col5" class="data row1 col5" >-0.1025</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row2" class="row_heading level0 row2" >Materials Science</th>
#       <td id="T_66b39_row2_col0" class="data row2 col0" >0.4316</td>
#       <td id="T_66b39_row2_col1" class="data row2 col1" >0.5118</td>
#       <td id="T_66b39_row2_col2" class="data row2 col2" >0.0803</td>
#       <td id="T_66b39_row2_col3" class="data row2 col3" >0.6422</td>
#       <td id="T_66b39_row2_col4" class="data row2 col4" >0.5540</td>
#       <td id="T_66b39_row2_col5" class="data row2 col5" >-0.0881</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row3" class="row_heading level0 row3" >Chemical Engineering</th>
#       <td id="T_66b39_row3_col0" class="data row3 col0" >0.3811</td>
#       <td id="T_66b39_row3_col1" class="data row3 col1" >0.7710</td>
#       <td id="T_66b39_row3_col2" class="data row3 col2" >0.3899</td>
#       <td id="T_66b39_row3_col3" class="data row3 col3" >0.5660</td>
#       <td id="T_66b39_row3_col4" class="data row3 col4" >0.7552</td>
#       <td id="T_66b39_row3_col5" class="data row3 col5" >0.1892</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row4" class="row_heading level0 row4" >Computer Science</th>
#       <td id="T_66b39_row4_col0" class="data row4 col0" >0.2142</td>
#       <td id="T_66b39_row4_col1" class="data row4 col1" >0.2578</td>
#       <td id="T_66b39_row4_col2" class="data row4 col2" >0.0436</td>
#       <td id="T_66b39_row4_col3" class="data row4 col3" >0.5151</td>
#       <td id="T_66b39_row4_col4" class="data row4 col4" >0.3021</td>
#       <td id="T_66b39_row4_col5" class="data row4 col5" >-0.2131</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row5" class="row_heading level0 row5" >Neuroscience</th>
#       <td id="T_66b39_row5_col0" class="data row5 col0" >0.4297</td>
#       <td id="T_66b39_row5_col1" class="data row5 col1" >0.6768</td>
#       <td id="T_66b39_row5_col2" class="data row5 col2" >0.2471</td>
#       <td id="T_66b39_row5_col3" class="data row5 col3" >0.5027</td>
#       <td id="T_66b39_row5_col4" class="data row5 col4" >0.6996</td>
#       <td id="T_66b39_row5_col5" class="data row5 col5" >0.1968</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row6" class="row_heading level0 row6" >Chemistry</th>
#       <td id="T_66b39_row6_col0" class="data row6 col0" >0.4675</td>
#       <td id="T_66b39_row6_col1" class="data row6 col1" >0.5986</td>
#       <td id="T_66b39_row6_col2" class="data row6 col2" >0.1311</td>
#       <td id="T_66b39_row6_col3" class="data row6 col3" >0.4807</td>
#       <td id="T_66b39_row6_col4" class="data row6 col4" >0.5047</td>
#       <td id="T_66b39_row6_col5" class="data row6 col5" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row7" class="row_heading level0 row7" >Mathematics</th>
#       <td id="T_66b39_row7_col0" class="data row7 col0" >0.2045</td>
#       <td id="T_66b39_row7_col1" class="data row7 col1" >0.2840</td>
#       <td id="T_66b39_row7_col2" class="data row7 col2" >0.0796</td>
#       <td id="T_66b39_row7_col3" class="data row7 col3" >0.4375</td>
#       <td id="T_66b39_row7_col4" class="data row7 col4" >0.4465</td>
#       <td id="T_66b39_row7_col5" class="data row7 col5" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row8" class="row_heading level0 row8" >Energy</th>
#       <td id="T_66b39_row8_col0" class="data row8 col0" >0.2746</td>
#       <td id="T_66b39_row8_col1" class="data row8 col1" >0.5620</td>
#       <td id="T_66b39_row8_col2" class="data row8 col2" >0.2873</td>
#       <td id="T_66b39_row8_col3" class="data row8 col3" >0.4164</td>
#       <td id="T_66b39_row8_col4" class="data row8 col4" >0.5101</td>
#       <td id="T_66b39_row8_col5" class="data row8 col5" >0.0936</td>
#     </tr>
#     <tr>
#       <th id="T_66b39_level0_row9" class="row_heading level0 row9" >V

# %%
df_f_dsharec.corr(method='spearman')
# Out:
#                           Pearson (All)  Pearson (50)  \
# Pearson (All)                  1.000000      0.551453
# Pearson (50)                   0.551453      1.000000
# Pearson Diff (50 - All)       -0.331966      0.515897
# Spearman (All)                 0.876923      0.437949
# Spearman (50)                  0.416068      0.760000
# Spearman Diff (50 - All)      -0.560342      0.193162
#
#                           Pearson Diff (50 - All)  Spearman (All)  \
# Pearson (All)                           -0.331966        0.876923
# Pearson (50)                             0.515897        0.437949
# Pearson Diff (50 - All)                  1.000000       -0.409915
# Spearman (All)                          -0.409915        1.000000
# Spearman (50)                            0.411282        0.499487
# Spearman Diff (50 - All)                 0.803761       -0.584957
#
#                           Spearman (50)  Spearman Diff (50 - All)
# Pearson (All)                  0.416068                 -0.560342
# Pearson (50)                   0.760000                  0.193162
# Pearson Diff (50 - All)        0.411282                  0.803761
# Spearman (All)                 0.499487                 -0.584957
# Spearman (50)                  1.000000                  0.351795
# Spearman Diff (50 - All)       0.351795                  1.000000

# %% [markdown]
# ## 4. F-Measure vs CShareD Correlation Comparison
#
# This section compares the correlations of **F-Measure** versus **CShareD**.

# %%
df_f_cshared = get_comparison_table('F-Measure vs CShareD')
display_styled_table(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'Table 4: F-Measure vs CShareD (All vs. 50)')
plot_comparison(df_f_cshared.sort_values('Spearman (All)', ascending=False), 'F-Measure vs CShareD')
# Out:
# <style type="text/css">
# #T_7f633 th {
#   background-color: #f4f6f7;
#   color: #2c3e50;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7f633 td {
#   text-align: right;
# }
# #T_7f633 caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_7f633_row0_col2, #T_7f633_row19_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_7f633_row0_col5, #T_7f633_row1_col2, #T_7f633_row1_col5, #T_7f633_row2_col5, #T_7f633_row3_col5, #T_7f633_row4_col5, #T_7f633_row5_col5, #T_7f633_row7_col2, #T_7f633_row14_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_7f633_row2_col2, #T_7f633_row5_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_7f633_row3_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7f633_row4_col2, #T_7f633_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_7f633_row6_col2, #T_7f633_row6_col5, #T_7f633_row7_col5, #T_7f633_row8_col5, #T_7f633_row9_col5, #T_7f633_row10_col5, #T_7f633_row11_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_7f633_row8_col2, #T_7f633_row12_col5, #T_7f633_row18_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_7f633_row10_col2, #T_7f633_row13_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_7f633_row11_col5, #T_7f633_row14_col5, #T_7f633_row18_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_7f633_row12_col2, #T_7f633_row15_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7f633_row13_col5, #T_7f633_row15_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_7f633_row16_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_7f633_row16_col5, #T_7f633_row17_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_7f633_row17_col2, #T_7f633_row23_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_7f633_row19_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_7f633_row20_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_7f633_row20_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_7f633_row21_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_7f633_row21_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_7f633_row22_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_7f633_row22_col5, #T_7f633_row24_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_7f633_row23_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_7f633_row24_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_7f633_row25_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7f633_row25_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# </style>
# <table id="T_7f633" class="dataframe">
#   <caption><b style='font-size: 14px;'>Table 4: F-Measure vs CShareD (All vs. 50)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f633_level0_col0" class="col_heading level0 col0" >Pearson (All)</th>
#       <th id="T_7f633_level0_col1" class="col_heading level0 col1" >Pearson (50)</th>
#       <th id="T_7f633_level0_col2" class="col_heading level0 col2" >Pearson Diff (50 - All)</th>
#       <th id="T_7f633_level0_col3" class="col_heading level0 col3" >Spearman (All)</th>
#       <th id="T_7f633_level0_col4" class="col_heading level0 col4" >Spearman (50)</th>
#       <th id="T_7f633_level0_col5" class="col_heading level0 col5" >Spearman Diff (50 - All)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f633_level0_row0" class="row_heading level0 row0" >Medicine</th>
#       <td id="T_7f633_row0_col0" class="data row0 col0" >0.9815</td>
#       <td id="T_7f633_row0_col1" class="data row0 col1" >0.9826</td>
#       <td id="T_7f633_row0_col2" class="data row0 col2" >0.0011</td>
#       <td id="T_7f633_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_7f633_row0_col4" class="data row0 col4" >0.9999</td>
#       <td id="T_7f633_row0_col5" class="data row0 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row1" class="row_heading level0 row1" >Social Sciences</th>
#       <td id="T_7f633_row1_col0" class="data row1 col0" >0.9869</td>
#       <td id="T_7f633_row1_col1" class="data row1 col1" >0.9867</td>
#       <td id="T_7f633_row1_col2" class="data row1 col2" >-0.0002</td>
#       <td id="T_7f633_row1_col3" class="data row1 col3" >0.9999</td>
#       <td id="T_7f633_row1_col4" class="data row1 col4" >0.9995</td>
#       <td id="T_7f633_row1_col5" class="data row1 col5" >-0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row2" class="row_heading level0 row2" >Environmental Science</th>
#       <td id="T_7f633_row2_col0" class="data row2 col0" >0.8850</td>
#       <td id="T_7f633_row2_col1" class="data row2 col1" >0.8919</td>
#       <td id="T_7f633_row2_col2" class="data row2 col2" >0.0069</td>
#       <td id="T_7f633_row2_col3" class="data row2 col3" >0.9999</td>
#       <td id="T_7f633_row2_col4" class="data row2 col4" >0.9995</td>
#       <td id="T_7f633_row2_col5" class="data row2 col5" >-0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row3" class="row_heading level0 row3" >Engineering</th>
#       <td id="T_7f633_row3_col0" class="data row3 col0" >0.9838</td>
#       <td id="T_7f633_row3_col1" class="data row3 col1" >0.9862</td>
#       <td id="T_7f633_row3_col2" class="data row3 col2" >0.0024</td>
#       <td id="T_7f633_row3_col3" class="data row3 col3" >0.9999</td>
#       <td id="T_7f633_row3_col4" class="data row3 col4" >0.9995</td>
#       <td id="T_7f633_row3_col5" class="data row3 col5" >-0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row4" class="row_heading level0 row4" >Computer Science</th>
#       <td id="T_7f633_row4_col0" class="data row4 col0" >0.9418</td>
#       <td id="T_7f633_row4_col1" class="data row4 col1" >0.9452</td>
#       <td id="T_7f633_row4_col2" class="data row4 col2" >0.0034</td>
#       <td id="T_7f633_row4_col3" class="data row4 col3" >0.9998</td>
#       <td id="T_7f633_row4_col4" class="data row4 col4" >0.9997</td>
#       <td id="T_7f633_row4_col5" class="data row4 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row5" class="row_heading level0 row5" >Biochemistry, Genetics and Molecular Biology</th>
#       <td id="T_7f633_row5_col0" class="data row5 col0" >0.8962</td>
#       <td id="T_7f633_row5_col1" class="data row5 col1" >0.9040</td>
#       <td id="T_7f633_row5_col2" class="data row5 col2" >0.0077</td>
#       <td id="T_7f633_row5_col3" class="data row5 col3" >0.9997</td>
#       <td id="T_7f633_row5_col4" class="data row5 col4" >0.9983</td>
#       <td id="T_7f633_row5_col5" class="data row5 col5" >-0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row6" class="row_heading level0 row6" >Agricultural and Biological Sciences</th>
#       <td id="T_7f633_row6_col0" class="data row6 col0" >0.9050</td>
#       <td id="T_7f633_row6_col1" class="data row6 col1" >0.9034</td>
#       <td id="T_7f633_row6_col2" class="data row6 col2" >-0.0016</td>
#       <td id="T_7f633_row6_col3" class="data row6 col3" >0.9996</td>
#       <td id="T_7f633_row6_col4" class="data row6 col4" >0.9980</td>
#       <td id="T_7f633_row6_col5" class="data row6 col5" >-0.0016</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row7" class="row_heading level0 row7" >Economics, Econometrics and Finance</th>
#       <td id="T_7f633_row7_col0" class="data row7 col0" >0.8395</td>
#       <td id="T_7f633_row7_col1" class="data row7 col1" >0.8394</td>
#       <td id="T_7f633_row7_col2" class="data row7 col2" >-0.0001</td>
#       <td id="T_7f633_row7_col3" class="data row7 col3" >0.9995</td>
#       <td id="T_7f633_row7_col4" class="data row7 col4" >0.9977</td>
#       <td id="T_7f633_row7_col5" class="data row7 col5" >-0.0018</td>
#     </tr>
#     <tr>
#       <th id="T_7f633_level0_row8" class="row_heading level0 row8" >Psychology</th>
#       <td id="T_7f633_row8_col0" class="data row8 col0" >0.8335</td>
#       <td id="T_7f633_row8_col1" class="data row8 col1" >0.8297</td>
#       <td id="T_7f633_row8_col2" class="data row8 col2" >-0.0039</td>
#       <td id="T_7f633_row8_col3" class="data row8 col3" >0.9995</td>
#       <td id="T_7f633_row8_col4" class="data

# %% [markdown]
# ## 5. Summary Statistics and Overall Analysis (Absolute Discrepancies)
#
# To synthesize the comparison, let's look at the summary statistics of the **absolute differences** across all 22 OpenAlex Fields for each of the four indicator pairs.
#
# Using absolute values is essential because it measures the magnitude of the discrepancy (change) regardless of whether the correlation went up or down. For example, a large negative change like -0.76708 represents a major discrepancy of 0.76708 in absolute terms. Computing statistics on signed differences can cause positive and negative changes to cancel each other out, hiding the true extent of the changes.

# %%
summary_data = []
pairs_mapping = {
    'AI vs DShareC': 'AI vs DShareC',
    'AI vs CShareD': 'AI vs CShareD',
    'F-Measure vs DShareC': 'F-Measure vs DShareC',
    'F-Measure vs CShareD': 'F-Measure vs CShareD'
}

for user_name, csv_name in pairs_mapping.items():
    df_p = get_comparison_table(csv_name)
    pearson_abs = df_p['Pearson Diff (50 - All)'].abs()
    spearman_abs = df_p['Spearman Diff (50 - All)'].abs()
    summary_data.append({
        'Indicator Pair': user_name,
        'Mean Abs Pearson Diff': pearson_abs.mean(),
        'Median Abs Pearson Diff': pearson_abs.median(),
        'Max Abs Pearson Diff': pearson_abs.max(),
        'Min Abs Pearson Diff': pearson_abs.min(),
        'Mean Abs Spearman Diff': spearman_abs.mean(),
        'Median Abs Spearman Diff': spearman_abs.median(),
        'Max Abs Spearman Diff': spearman_abs.max(),
        'Min Abs Spearman Diff': spearman_abs.min()
    })

df_summary = pd.DataFrame(summary_data).set_index('Indicator Pair')

styled_summary = df_summary.style.format("{:.5f}")\
    .background_gradient(cmap="Reds", vmin=0.0, vmax=0.3)\
    .set_caption("<b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|50 - All|)</b>")\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#2c3e50'), ('color', 'white'), ('font-weight', 'bold'), ('text-align', 'center')]},
        {'selector': 'td', 'props': [('text-align', 'right')]},
        {'selector': 'caption', 'props': [('margin-bottom', '10px'), ('color', '#2c3e50')]}
    ])
display(styled_summary)
global text
text = text + "<h2>Overall Comparison Summary</h2>" + styled_summary.to_html() + "<br><br>"
# Out:
# <style type="text/css">
# #T_f90ad th {
#   background-color: #2c3e50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f90ad td {
#   text-align: right;
# }
# #T_f90ad caption {
#   margin-bottom: 10px;
#   color: #2c3e50;
# }
# #T_f90ad_row0_col0, #T_f90ad_row0_col1, #T_f90ad_row0_col2, #T_f90ad_row0_col3, #T_f90ad_row0_col4, #T_f90ad_row0_col5, #T_f90ad_row0_col6, #T_f90ad_row0_col7, #T_f90ad_row1_col7, #T_f90ad_row3_col3, #T_f90ad_row3_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f90ad_row1_col0 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_f90ad_row1_col1 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_f90ad_row1_col2 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_f90ad_row1_col3 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_f90ad_row1_col4 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_f90ad_row1_col5 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_f90ad_row1_col6, #T_f90ad_row2_col2, #T_f90ad_row2_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f90ad_row2_col0 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_f90ad_row2_col1 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_f90ad_row2_col3, #T_f90ad_row2_col7 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_f90ad_row2_col4 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_f90ad_row2_col5 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_f90ad_row3_col0, #T_f90ad_row3_col4 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_f90ad_row3_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_f90ad_row3_col2 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_f90ad_row3_col5 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_f90ad_row3_col6 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# </style>
# <table id="T_f90ad" class="dataframe">
#   <caption><b style='font-size: 14px;'>Overall Comparison Summary: Absolute Discrepancies (|50 - All|)</b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f90ad_level0_col0" class="col_heading level0 col0" >Mean Abs Pearson Diff</th>
#       <th id="T_f90ad_level0_col1" class="col_heading level0 col1" >Median Abs Pearson Diff</th>
#       <th id="T_f90ad_level0_col2" class="col_heading level0 col2" >Max Abs Pearson Diff</th>
#       <th id="T_f90ad_level0_col3" class="col_heading level0 col3" >Min Abs Pearson Diff</th>
#       <th id="T_f90ad_level0_col4" class="col_heading level0 col4" >Mean Abs Spearman Diff</th>
#       <th id="T_f90ad_level0_col5" class="col_heading level0 col5" >Median Abs Spearman Diff</th>
#       <th id="T_f90ad_level0_col6" class="col_heading level0 col6" >Max Abs Spearman Diff</th>
#       <th id="T_f90ad_level0_col7" class="col_heading level0 col7" >Min Abs Spearman Diff</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Indicator Pair</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f90ad_level0_row0" class="row_heading level0 row0" >AI vs DShareC</th>
#       <td id="T_f90ad_row0_col0" class="data row0 col0" >0.00000</td>
#       <td id="T_f90ad_row0_col1" class="data row0 col1" >0.00000</td>
#       <td id="T_f90ad_row0_col2" class="data row0 col2" >0.00000</td>
#       <td id="T_f90ad_row0_col3" class="data row0 col3" >0.00000</td>
#       <td id="T_f90ad_row0_col4" class="data row0 col4" >0.00000</td>
#       <td id="T_f90ad_row0_col5" class="data row0 col5" >0.00000</td>
#       <td id="T_f90ad_row0_col6" class="data row0 col6" >0.00000</td>
#       <td id="T_f90ad_row0_col7" class="data row0 col7" >0.00000</td>
#     </tr>
#     <tr>
#       <th id="T_f90ad_level0_row1" class="row_heading level0 row1" >AI vs CShareD</th>
#       <td id="T_f90ad_row1_col0" class="data row1 col0" >0.11698</td>
#       <td id="T_f90ad_row1_col1" class="data row1 col1" >0.11947</td>
#       <td id="T_f90ad_row1_col2" class="data row1 col2" >0.25799</td>
#       <td id="T_f90ad_row1_col3" class="data row1 col3" >0.02577</td>
#       <td id="T_f90ad_row1_col4" class="data row1 col4" >0.20902</td>
#       <td id="T_f90ad_row1_col5" class="data row1 col5" >0.17721</td>
#       <td id="T_f90ad_row1_col6" class="data row1 col6" >0.56385</td>
#       <td id="T_f90ad_row1_col7" class="data row1 col7" >0.00036</td>
#     </tr>
#     <tr>
#       <th id="T_f90ad_level0_row2" class="row_heading level0 row2" >F-Measure vs DShareC</th>
#       <td id="T_f90ad_row2_col0" class="data row2 col0" >0.26826</td>
#       <td id="T_f90ad_row2_col1" class="data row2 col1" >0.23013</td>
#       <td id="T_f90ad_row2_col2" class="data row2 col2" >0.75416</td>
#       <td id="T_f90ad_row2_col3" class="data row2 col3" >0.00468</td>
#       <td id="T_f90ad_row2_col4" class="data row2 col4" >0.23812</td>
#       <td id="T_f90ad_row2_col5" class="data row2 col5" >0.20495</td>
#       <td id="T_f90ad_row2_col6" class="data row2 col6" >0.70144</td>
#       <td id="T_f90ad_row2_col7" class="data row2 col7" >0.00409</td>
#     </tr>
#     <tr>
#       <th id="T_f90ad_level0_row3" class="row_heading level0 row3" >F-Measure vs CShareD</th>
#       <td id="T_f90ad_row3_col0" class="data row3 col0" >0.01291</td>
#       <td id="T_f90ad_row3_col1" class="data row3 col1" >0.00733</td>
#       <td id="T_f90ad_row3_col2" class="data row3 col2" >0.06956</td>
#       <td id="T_f90ad_row3_col3" class="data row3 col3" >0.00008</td>
#       <td id="T_f90ad_row3_col4" class="data row3 col4" >0.01389</td>
#       <td id="T_f90ad_row3_col5" class="data row3 col5" >0.00540</td>
#       <td id="T_f90ad_row3_col6" class="data row3 col6" >0.10418</td>
#       <td id="T_f90ad_row3_col7" class="data row3 col7" >0.00011</td>
#     </tr>
#   </tbody>
# </table>

# %%
global text
text = text + "</body></html>"
with open("All_vs_50 Units.html", "w", encoding="utf-8") as f:
    f.write(text)
print("Saved report to All_vs_50 Units.html")
# Out:
# Saved report to All_vs_50 Units.html
